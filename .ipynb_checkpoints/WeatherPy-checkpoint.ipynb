# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from itertools import combinations
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lon=[]
temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
city_list = []

#count records and set numbers
record_num = 0
set_num = 1

# %%
print('''
Beginning Data Retrieval     
-----------------------------
''')   

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num ==50:
            set_num += 1
            record_num = 1 
            city_list.append(city)
        
        else:
            record_num += 1 
            city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city} ")
    
    except (KeyError,IndexError):
        print ("City not found. Skipping...")
        
print('''
Data Retrieval Complete    
-----------------------------
''')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# City not found. Skipping...
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | klaksvik
# City not found. Skipping...
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | nanakuli
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | marica
# Processing Record 10 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 11 of Set 1 | nushki
# Processing Record 12 of Set 1 | sosnogorsk
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mabaruma
# Processing Record 15 of Set 1 | bilma
# City not found. Skipping...
# Processing Record 16 of Set 1 | ust-ilimsk
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | rio gallegos
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | mitsamiouli
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | alta floresta
# Processing Record 28 of Set 1 | chumikan
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | prenzlau
# Processing Record 32 of Set 1 | agadez
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 1 | xiongyue
# Processing Record 34 of Set 1 | pitimbu
# Processing Record 35 of Set 1 | port lincoln
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | seymchan
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | passagem franca
# Processing Record 48 of Set 1 | shasta lake
# Processing Record 49 of Set 1 | ode
# Processing Record 50 of Set 1 | iseyin
# Processing Record 1 of Set 2 | erenhot
# City not found. Skipping...
# Processing Record 2 of Set 2 | rujiena
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 6 of Set 2 | novyy urengoy
# City not found. Skipping...
# Processing Record 7 of Set 2 | peiting
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | kapchorwa
# Processing Record 10 of Set 2 | nizhniy baskunchak
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | marrakesh
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | flin flon
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | olafsvik
# Processing Record 19 of Set 2 | huarmey
# Processing Record 20 of Set 2 | along
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | launceston
# Processing Record 26 of Set 2 | joao pessoa
# Processing Record 27 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 28 of Set 2 | montepuez
# Processing Record 29 of Set 2 | vestmannaeyjar
# Processing Record 30 of Set 2 | young
# Processing Record 31 of Set 2 | bintulu
# Processing Record 32 of Set 2 | aksarka
# Processing Record 33 of Set 2 | saint-pierre
# Processing Record 34 of Set 2 | yerbogachen
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | port macquarie
# Processing Record 38 of Set 2 | mason city
# Processing Record 39 of Set 2 | palu
# Processing Record 40 of Set 2 | chapais
# Processing Record 41 of Set 2 | obzor
# Processing Record 42 of Set 2 | umm lajj
# Processing Record 43 of Set 2 | araouane
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | north battleford
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | korla
# Processing Record 1 of Set 3 | abnub
# Processing Record 2 of Set 3 | ballina
# Processing Record 3 of Set 3 | maniwaki
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | odweyne
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | poum
# Processing Record 9 of Set 3 | tahta
# Processing Record 10 of Set 3 | parrita
# City not found. Skipping...
# Processing Record 11 of Set 3 | tessalit
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | surt
# Processing Record 14 of Set 3 | anchorage
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | aborlan
# Processing Record 23 of Set 3 | vardo
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | monroe
# Processing Record 26 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 27 of Set 3 | sao felix do xingu
# Processing Record 28 of Set 3 | okrika
# Processing Record 29 of Set 3 | kuching
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | datong
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | cayenne
# Processing Record 35 of Set 3 | mayumba
# Processing Record 36 of Set 3 | north bend
# Processing Record 37 of Set 3 | tiksi
# Processing Record 38 of Set 3 | manaure
# Processing Record 39 of Set 3 | shingu
# Processing Record 40 of Set 3 | tipitapa
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | comodoro rivadavia
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | talara
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | barrow
# Processing Record 49 of Set 3 | torbay
# Processing Record 50 of Set 3 | guerrero negro
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | goba
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | jasper
# City not found. Skipping...
# Processing Record 5 of Set 4 | bhigvan
# City not found. Skipping...
# Processing Record 6 of Set 4 | bereda
# Processing Record 7 of Set 4 | nongstoin
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | tadine
# City not found. Skipping...
# Processing Record 11 of Set 4 | port alfred
# City not found. Skipping...
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | ushtobe
# Processing Record 14 of Set 4 | kuryk
# Processing Record 15 of Set 4 | gaffney
# Processing Record 16 of Set 4 | fortuna
# City not found. Skipping...
# Processing Record 17 of Set 4 | santa maria
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | tres arroyos
# Processing Record 20 of Set 4 | jagdalpur
# Processing Record 21 of Set 4 | bubaque
# City not found. Skipping...
# Processing Record 22 of Set 4 | kipini
# Processing Record 23 of Set 4 | marawi
# Processing Record 24 of Set 4 | bengkulu
# Processing Record 25 of Set 4 | mar del plata
# Processing Record 26 of Set 4 | santa catarina de tepehuanes
# City not found. Skipping...
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | gurupa
# Processing Record 31 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 32 of Set 4 | awjilah
# City not found. Skipping...
# Processing Record 33 of Set 4 | amalapuram
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | asfi
# City not found. Skipping...
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | omboue
# Processing Record 38 of Set 4 | fort frances
# Processing Record 39 of Set 4 | saint-philippe
# City not found. Skipping...
# Processing Record 40 of Set 4 | bonfim
# Processing Record 41 of Set 4 | jijiga
# Processing Record 42 of Set 4 | toamasina
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | moose factory
# Processing Record 45 of Set 4 | progreso
# City not found. Skipping...
# Processing Record 46 of Set 4 | elizabeth city
# Processing Record 47 of Set 4 | angoram
# Processing Record 48 of Set 4 | ahipara
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | samarai
# City not found. Skipping...
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | houston
# Processing Record 3 of Set 5 | boda
# Processing Record 4 of Set 5 | karratha
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | ust-kut
# Processing Record 7 of Set 5 | ostrovnoy
# Processing Record 8 of Set 5 | paragominas
# Processing Record 9 of Set 5 | dera bugti
# Processing Record 10 of Set 5 | sesheke
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | bandar
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | ruzhyn
# Processing Record 17 of Set 5 | marzuq
# Processing Record 18 of Set 5 | biltine
# Processing Record 19 of Set 5 | dzilam gonzalez
# Processing Record 20 of Set 5 | sao geraldo do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 5 | yumen
# Processing Record 22 of Set 5 | energeticheskiy
# Processing Record 23 of Set 5 | esso
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | itarema
# Processing Record 26 of Set 5 | puerto rondon
# Processing Record 27 of Set 5 | thinadhoo
# Processing Record 28 of Set 5 | prestea
# Processing Record 29 of Set 5 | arluno
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | tianpeng
# City not found. Skipping...
# Processing Record 33 of Set 5 | lovington
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | eyrarbakki
# Processing Record 36 of Set 5 | bani walid
# Processing Record 37 of Set 5 | maryville
# Processing Record 38 of Set 5 | indramayu
# Processing Record 39 of Set 5 | villamontes
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | konevo
# Processing Record 42 of Set 5 | thompson
# Processing Record 43 of Set 5 | praia da vitoria
# Processing Record 44 of Set 5 | mwene-ditu
# Processing Record 45 of Set 5 | ginir
# City not found. Skipping...
# Processing Record 46 of Set 5 | rosetown
# Processing Record 47 of Set 5 | broome
# Processing Record 48 of Set 5 | hovd
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | aberdeen
# Processing Record 1 of Set 6 | aban
# Processing Record 2 of Set 6 | barcelos
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | caravelas
# City not found. Skipping...
# Processing Record 5 of Set 6 | atar
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | charlestown
# Processing Record 8 of Set 6 | hastings
# Processing Record 9 of Set 6 | coquimbo
# Processing Record 10 of Set 6 | casper
# Processing Record 11 of Set 6 | kruisfontein
# City not found. Skipping...
# Processing Record 12 of Set 6 | daru
# Processing Record 13 of Set 6 | bara
# Processing Record 14 of Set 6 | ashoknagar
# City not found. Skipping...
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | takoradi
# Processing Record 17 of Set 6 | londoko
# Processing Record 18 of Set 6 | puerto escondido
# Processing Record 19 of Set 6 | polyarnyy
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | mizan teferi
# Processing Record 22 of Set 6 | kihei
# Processing Record 23 of Set 6 | luwuk
# Processing Record 24 of Set 6 | yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 6 | camana
# Processing Record 26 of Set 6 | kushima
# Processing Record 27 of Set 6 | coahuayana
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | tocopilla
# Processing Record 30 of Set 6 | itoman
# Processing Record 31 of Set 6 | sur
# Processing Record 32 of Set 6 | beyneu
# Processing Record 33 of Set 6 | weihai
# Processing Record 34 of Set 6 | madimba
# Processing Record 35 of Set 6 | sumbawanga
# Processing Record 36 of Set 6 | marshall
# Processing Record 37 of Set 6 | lerwick
# Processing Record 38 of Set 6 | najran
# Processing Record 39 of Set 6 | fort nelson
# Processing Record 40 of Set 6 | bismarck
# Processing Record 41 of Set 6 | simpang
# Processing Record 42 of Set 6 | el alto
# Processing Record 43 of Set 6 | pacific grove
# City not found. Skipping...
# Processing Record 44 of Set 6 | dongobesh
# Processing Record 45 of Set 6 | jalu
# City not found. Skipping...
# Processing Record 46 of Set 6 | nanortalik
# Processing Record 47 of Set 6 | hualmay
# Processing Record 48 of Set 6 | nome
# Processing Record 49 of Set 6 | baiyin
# Processing Record 50 of Set 6 | muli
# Processing Record 1 of Set 7 | bonthe
# Processing Record 2 of Set 7 | juneau
# City not found. Skipping...
# Processing Record 3 of Set 7 | kamenka
# Processing Record 4 of Set 7 | luderitz
# Processing Record 5 of Set 7 | flinders
# City not found. Skipping...
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | dunmore east
# Processing Record 8 of Set 7 | bethel
# Processing Record 9 of Set 7 | morehead
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | manzhouli
# Processing Record 12 of Set 7 | asilah
# Processing Record 13 of Set 7 | bollnas
# Processing Record 14 of Set 7 | sulangan
# Processing Record 15 of Set 7 | sribne
# Processing Record 16 of Set 7 | bogovarovo
# Processing Record 17 of Set 7 | sambava
# Processing Record 18 of Set 7 | sangar
# Processing Record 19 of Set 7 | morondava
# Processing Record 20 of Set 7 | adrar
# Processing Record 21 of Set 7 | aksu
# Processing Record 22 of Set 7 | bayonet point
# Processing Record 23 of Set 7 | agirish
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint-francois
# Processing Record 25 of Set 7 | almaznyy
# Processing Record 26 of Set 7 | mindelo
# Processing Record 27 of Set 7 | lata
# Processing Record 28 of Set 7 | pimentel
# Processing Record 29 of Set 7 | wattegama
# Processing Record 30 of Set 7 | suoyarvi
# Processing Record 31 of Set 7 | dumfries
# Processing Record 32 of Set 7 | mackay
# Processing Record 33 of Set 7 | samfya
# Processing Record 34 of Set 7 | morong
# Processing Record 35 of Set 7 | albury
# Processing Record 36 of Set 7 | maneadero
# Processing Record 37 of Set 7 | sijunjung
# Processing Record 38 of Set 7 | erzin
# Processing Record 39 of Set 7 | mmabatho
# Processing Record 40 of Set 7 | zhigansk
# Processing Record 41 of Set 7 | bykovo
# Processing Record 42 of Set 7 | tilichiki
# Processing Record 43 of Set 7 | great yarmouth
# Processing Record 44 of Set 7 | urusha
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | rybnaya sloboda
# Processing Record 47 of Set 7 | maniitsoq
# City not found. Skipping...
# Processing Record 48 of Set 7 | dores do indaia
# Processing Record 49 of Set 7 | jiuquan
# Processing Record 50 of Set 7 | northam
# Processing Record 1 of Set 8 | kholtoson
# Processing Record 2 of Set 8 | aswan
# Processing Record 3 of Set 8 | pokosnoye
# Processing Record 4 of Set 8 | nhulunbuy
# Processing Record 5 of Set 8 | mehamn
# Processing Record 6 of Set 8 | mala
# Processing Record 7 of Set 8 | ewa beach
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | porto novo
# Processing Record 10 of Set 8 | padang
# Processing Record 11 of Set 8 | rincon
# Processing Record 12 of Set 8 | mahebourg
# Processing Record 13 of Set 8 | moskovskiy
# Processing Record 14 of Set 8 | malumfashi
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | pahrump
# Processing Record 17 of Set 8 | lundazi
# Processing Record 18 of Set 8 | sakakah
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | paengaroa
# Processing Record 21 of Set 8 | oussouye
# Processing Record 22 of Set 8 | paita
# City not found. Skipping...
# Processing Record 23 of Set 8 | alyangula
# Processing Record 24 of Set 8 | leshukonskoye
# Processing Record 25 of Set 8 | champerico
# Processing Record 26 of Set 8 | binga
# Processing Record 27 of Set 8 | aden
# Processing Record 28 of Set 8 | altay
# City not found. Skipping...
# Processing Record 29 of Set 8 | klyuchi
# Processing Record 30 of Set 8 | aykhal
# Processing Record 31 of Set 8 | kloulklubed
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | acari
# Processing Record 34 of Set 8 | yeniseysk
# Processing Record 35 of Set 8 | fort-shevchenko
# City not found. Skipping...
# Processing Record 36 of Set 8 | porto velho
# Processing Record 37 of Set 8 | staryy krym
# Processing Record 38 of Set 8 | tawang
# Processing Record 39 of Set 8 | kieta
# Processing Record 40 of Set 8 | san diego de los banos
# Processing Record 41 of Set 8 | shelburne
# Processing Record 42 of Set 8 | blagoveshchenka
# Processing Record 43 of Set 8 | isangel
# Processing Record 44 of Set 8 | tutoia
# Processing Record 45 of Set 8 | margate
# Processing Record 46 of Set 8 | abalak
# Processing Record 47 of Set 8 | mitu
# Processing Record 48 of Set 8 | kosh
# Processing Record 49 of Set 8 | george
# Processing Record 50 of Set 8 | shimoda
# City not found. Skipping...
# Processing Record 1 of Set 9 | kavaratti
# Processing Record 2 of Set 9 | arkhangelsk
# Processing Record 3 of Set 9 | kars
# Processing Record 4 of Set 9 | general jose eduvigis diaz
# Processing Record 5 of Set 9 | pochutla
# Processing Record 6 of Set 9 | umm kaddadah
# Processing Record 7 of Set 9 | banda aceh
# Processing Record 8 of Set 9 | krasnorechenskiy
# Processing Record 9 of Set 9 | teya
# Processing Record 10 of Set 9 | whyalla
# Processing Record 11 of Set 9 | zwedru
# Processing Record 12 of Set 9 | sisimiut
# Processing Record 13 of Set 9 | north platte
# Processing Record 14 of Set 9 | panama city
# Processing Record 15 of Set 9 | derazhnya
# Processing Record 16 of Set 9 | japura
# Processing Record 17 of Set 9 | san pedro
# Processing Record 18 of Set 9 | kailua
# Processing Record 19 of Set 9 | key west
# Processing Record 20 of Set 9 | newport
# Processing Record 21 of Set 9 | moerai
# Processing Record 22 of Set 9 | nagutskoye
# Processing Record 23 of Set 9 | kholodnyy
# Processing Record 24 of Set 9 | riyadh
# Processing Record 25 of Set 9 | sao gabriel da cachoeira
# Processing Record 26 of Set 9 | shahr-e babak
# Processing Record 27 of Set 9 | honningsvag
# Processing Record 28 of Set 9 | prince rupert
# Processing Record 29 of Set 9 | oytal
# Processing Record 30 of Set 9 | vrangel
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | boden
# Processing Record 33 of Set 9 | college
# City not found. Skipping...
# Processing Record 34 of Set 9 | lannion
# Processing Record 35 of Set 9 | ust-tarka
# Processing Record 36 of Set 9 | jizan
# Processing Record 37 of Set 9 | havelian
# Processing Record 38 of Set 9 | kralendijk
# Processing Record 39 of Set 9 | linguere
# Processing Record 40 of Set 9 | salalah
# Processing Record 41 of Set 9 | belmonte
# Processing Record 42 of Set 9 | abilene
# Processing Record 43 of Set 9 | popondetta
# Processing Record 44 of Set 9 | taltal
# Processing Record 45 of Set 9 | camacha
# City not found. Skipping...
# Processing Record 46 of Set 9 | luba
# Processing Record 47 of Set 9 | russell
# Processing Record 48 of Set 9 | batetskiy
# Processing Record 49 of Set 9 | siderno
# Processing Record 50 of Set 9 | goure
# Processing Record 1 of Set 10 | da nang
# Processing Record 2 of Set 10 | fare
# Processing Record 3 of Set 10 | dudinka
# Processing Record 4 of Set 10 | acarau
# Processing Record 5 of Set 10 | peniche
# Processing Record 6 of Set 10 | seoul
# Processing Record 7 of Set 10 | eregli
# Processing Record 8 of Set 10 | karpogory
# Processing Record 9 of Set 10 | ascension
# Processing Record 10 of Set 10 | klamath falls
# City not found. Skipping...
# Processing Record 11 of Set 10 | union
# Processing Record 12 of Set 10 | pemangkat
# Processing Record 13 of Set 10 | nago
# Processing Record 14 of Set 10 | parabel
# Processing Record 15 of Set 10 | rabo de peixe
# Processing Record 16 of Set 10 | bathsheba
# Processing Record 17 of Set 10 | krupanj
# Processing Record 18 of Set 10 | bairiki
# Processing Record 19 of Set 10 | seelze
# Processing Record 20 of Set 10 | khandyga
# Processing Record 21 of Set 10 | makokou
# Processing Record 22 of Set 10 | tiznit
# Processing Record 23 of Set 10 | mahajanga
# Processing Record 24 of Set 10 | magnor
# Processing Record 25 of Set 10 | novaya zaimka
# Processing Record 26 of Set 10 | saint-joseph
# Processing Record 27 of Set 10 | banjar
# City not found. Skipping...
# Processing Record 28 of Set 10 | mecca
# Processing Record 29 of Set 10 | watrous
# Processing Record 30 of Set 10 | moussoro
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | srednekolymsk
# Processing Record 33 of Set 10 | shuiji
# Processing Record 34 of Set 10 | saint-paul
# Processing Record 35 of Set 10 | port-cartier
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | carbonia
# City not found. Skipping...
# Processing Record 38 of Set 10 | afua
# City not found. Skipping...
# Processing Record 39 of Set 10 | remanso
# Processing Record 40 of Set 10 | zhangye
# City not found. Skipping...
# Processing Record 41 of Set 10 | beroroha
# Processing Record 42 of Set 10 | vilyuysk
# Processing Record 43 of Set 10 | kabinda
# Processing Record 44 of Set 10 | rocky mountain house
# Processing Record 45 of Set 10 | qaqortoq
# Processing Record 46 of Set 10 | necochea
# Processing Record 47 of Set 10 | dunedin
# Processing Record 48 of Set 10 | boa vista
# Processing Record 49 of Set 10 | shaowu
# City not found. Skipping...
# Processing Record 50 of Set 10 | nioro
# Processing Record 1 of Set 11 | verkhozim
# Processing Record 2 of Set 11 | makurdi
# Processing Record 3 of Set 11 | alice town
# Processing Record 4 of Set 11 | deputatskiy
# Processing Record 5 of Set 11 | turukhansk
# Processing Record 6 of Set 11 | lagoa
# Processing Record 7 of Set 11 | faya
# Processing Record 8 of Set 11 | hofn
# Processing Record 9 of Set 11 | kamennomostskiy
# Processing Record 10 of Set 11 | belaya gora
# Processing Record 11 of Set 11 | porto santo
# Processing Record 12 of Set 11 | duluth
# Processing Record 13 of Set 11 | hammerfest
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | brainerd
# City not found. Skipping...
# Processing Record 16 of Set 11 | pathalgaon
# Processing Record 17 of Set 11 | middelburg
# Processing Record 18 of Set 11 | hoquiam
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | turka
# City not found. Skipping...
# Processing Record 21 of Set 11 | tagakpan
# Processing Record 22 of Set 11 | glinka
# Processing Record 23 of Set 11 | piedras negras
# Processing Record 24 of Set 11 | odienne
# Processing Record 25 of Set 11 | vanavara
# Processing Record 26 of Set 11 | boskoop
# Processing Record 27 of Set 11 | maragogi
# Processing Record 28 of Set 11 | sioux lookout
# Processing Record 29 of Set 11 | ust-nera
# Processing Record 30 of Set 11 | gloucester
# Processing Record 31 of Set 11 | praia
# Processing Record 32 of Set 11 | raga
# Processing Record 33 of Set 11 | sulechow
# Processing Record 34 of Set 11 | marsa matruh
# Processing Record 35 of Set 11 | snezhnogorsk
# Processing Record 36 of Set 11 | kiama
# Processing Record 37 of Set 11 | poya
# Processing Record 38 of Set 11 | coihueco
# Processing Record 39 of Set 11 | horta
# Processing Record 40 of Set 11 | mulchen
# Processing Record 41 of Set 11 | kimbe
# Processing Record 42 of Set 11 | sinazongwe
# Processing Record 43 of Set 11 | kudahuvadhoo
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | moron
# Processing Record 46 of Set 11 | jacmel
# Processing Record 47 of Set 11 | qeshm
# Processing Record 48 of Set 11 | horasan
# Processing Record 49 of Set 11 | tautira
# City not found. Skipping...
# Processing Record 50 of Set 11 | bela
# Processing Record 1 of Set 12 | kunri
# Processing Record 2 of Set 12 | richards bay
# Processing Record 3 of Set 12 | cotonou
# Processing Record 4 of Set 12 | luoyang
# Processing Record 5 of Set 12 | fukue
# City not found. Skipping...
#
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
#create dictionary to dreate data frame
city_dict = {
    "City": city_list,
    "Lat": lat, 
    "Lng": lon, 
    "Max Temp": temp, 
    "Humidity": humidity,
    "Cloudiness": clouds, 
    "Wind Speed": wind_speed, 
    "Country": country, 
    "Date": date }
    
#create data frame
city_dict= pd.DataFrame(city_dict)

# %%
#export the city data into a .csv.
city_dict.to_csv("cities.csv", index=False)

# %%
#print dataframe
weather_df= pd.DataFrame(city_dict)
weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           mataura -46.1927  168.8643     42.48        94          82
# 1            castro -24.7911  -50.0119     53.83        93          62
# 2          klaksvik  62.2266   -6.5890     54.52        99         100
# 3    ribeira grande  38.5167  -28.7000     63.00        82          40
# 4          cidreira -30.1811  -50.2056     61.86        87          99
# ..              ...      ...       ...       ...       ...         ...
# 550           kunri  25.1785   69.5691     96.82        44         100
# 551    richards bay -28.7830   32.0377     63.28        84         100
# 552         cotonou   6.3654    2.4183     78.78        89          40
# 553         luoyang  34.6836  112.4536     83.23        44           6
# 554           fukue  32.6881  128.8419     82.76        89          75
#
#      Wind Speed Country        Date
# 0          9.91      NZ  1631001265
# 1          8.12      BR  1631001266
# 2         13.49      FO  1631001266
# 3          5.75      PT  1631001267
# 4         23.00      BR  1631001267
# ..          ...     ...         ...
# 550        6.82      PK  1631001500
# 551       11.77      ZA  1631001500
# 552       10.36      BJ  1631001501
# 553        3.06      CN  1631001501
# 554       10.36      JP  1631001502
#
# [555 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.figure(figsize=[10,5])

# Plot the lat vs the max temp
plt.scatter(x = latitude, y = temperature)

# Add labeling
# This extracts the date and returns it in the local time zone
# lat_time_plt = datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
# plt.xlim(-80,100)
# plt.ylim(min(temperature) - 10 , max(temperature) +10)
plt.savefig('Images/Latitude_vs_Temperature_Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how hot the temperature gets along all latitudes of the selected cities. We can see that the hottest temperatures happen between -20 and 40 latitude which would include the contries of Africa and Europe.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs humidity
plt.scatter(x = weather_df['Lat'], y = weather_df['Humidity']);

# Add labeling
# This extracts the date and returns it in the local time zone
plt.title(f"Latitude vs. Humidity({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Humidity");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(humidity) - 10 , max(humidity) +10);
plt.savefig('Images/Latitude_vs_Humidity_Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how humid gets along all latitudes of the selected cities. We do not see a real relationship represented here.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Cloudiness
plt.scatter(x = weather_df['Lat'], y = weather_df['Cloudiness']);

# Add labeling
# This extracts the date and returns it in the local time zone

plt.title(f"Latitude vs. Cloudiness({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Cloudiness");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) - 10 , max(clouds) +10);
plt.savefig('Images/Latitude_vs_Cloudiness_Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how cloudy it gets along all latitudes of the selected cities. We do not see a real relationship represented here.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Wind
plt.scatter(x = weather_df['Lat'], y = weather_df['Wind Speed']);

# Add labeling
plt.title(f"Latitude vs. Wind Speed ({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Wind Speeds");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) , max(clouds) );
plt.savefig('Images/Latitude_vs_Wind_Speed_Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how windy it gets along all latitudes of the selected cities. We see that wind speeds tend to stay under 40mph along all latitudes.

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_df[weather_df['Lat']>=0]
southern = weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Max Temp'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/NH_MaxTemp_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.6024776506267218

# %% [markdown]
#  This plot is analyzing the relationship between a city's temperature and latitude where the city is within the Norther Hemisphere. Here we see temperatures are lower in cities where the latitude is higher. This information implies that the further away from the equator a city is, the colder it will be. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Max Temp'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/SH_MaxTemp_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.6103265784558866

# %% [markdown]
# This plot is analyzing the relationship between a city's temperature and latitude where the city is within the Southern Hemisphere. Here we see temperatures are higher in cities where the latitude is lower. This information implies that the closer from the equator a city is, the warmer it will be. Our r value confirms this.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Humidity'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/NH_Humidity_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.002346644959105904

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between humidity and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Humidity'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/SH_Humidity_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.00027158651180702556

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between humidity and latitude. Our r value confirms this.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Cloudiness'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/NH_Cloudiness_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.003030912991516805

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Cloudiness'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/SH_Cloudiness_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.02214820005996666

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# We do, however, notice that the Northern Hemisphere is cloudier than the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Wind Speed'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/NH_Windspeed_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.007449093831220206

# %% [markdown]
# This plot is analyzing the relationship between a city's windspeed and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Wind Speed'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Images/SH_Windspeed_vs_Latitude_Linear_Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0012020378928875978

# %% [markdown]
# This plot is analyzing the relationship between a city's windspeed and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.
