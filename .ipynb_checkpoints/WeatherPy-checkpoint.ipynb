# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from itertools import combinations
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lon=[]
temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
city_list = []

#count records and set numbers
record_num = 0
set_num = 1

# %%
print('''
Beginning Data Retrieval     
-----------------------------
''')   

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num ==50:
            set_num += 1
            record_num = 1 
            city_list.append(city)
        
        else:
            record_num += 1 
            city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city} ")
    
    except (KeyError,IndexError):
        print ("City not found. Skipping...")
        
print('''
Data Retrieval Complete    
-----------------------------
''')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 3 of Set 1 | kaeo
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | malinovoye ozero
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | punta de bombon
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | dunedin
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | brae
# Processing Record 16 of Set 1 | suez
# Processing Record 17 of Set 1 | shache
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | rock hill
# Processing Record 22 of Set 1 | karasjok
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | kajaani
# Processing Record 25 of Set 1 | sahuaripa
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | broome
# Processing Record 28 of Set 1 | karakol
# Processing Record 29 of Set 1 | east wenatchee bench
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | kungurtug
# Processing Record 32 of Set 1 | plainview
# Processing Record 33 of Set 1 | tilichiki
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | bandarbeyla
# Processing Record 38 of Set 1 | likasi
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | krosno odrzanskie
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | uyemskiy
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | mareeba
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | bon accord
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | qunduz
# City not found. Skipping...
# Processing Record 3 of Set 2 | fairbanks
# Processing Record 47 of Set 4 | chamba
# Processing Record 48 of Set 4 | erzin
# Processing Record 49 of Set 4 | petapa
# Processing Record 50 of Set 4 | shimoda
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | vikhorevka
# Processing Record 3 of Set 5 | seoul
# Processing Record 4 of Set 5 | ptuj
# Processing Record 5 of Set 5 | tilbury
# Processing Record 6 of Set 5 | benguela
# Processing Record 7 of Set 5 | ambon
# Processing Record 8 of Set 5 | oskaloosa
# Processing Record 9 of Set 5 | manzhouli
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | mazatlan
# Processing Record 12 of Set 5 | pallasovka
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | bued
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | narsaq
# Processing Record 18 of Set 5 | sumbe
# Processing Record 19 of Set 5 | grand bank
# City not found. Skipping...
# Processing Record 20 of Set 5 | sibu
# Processing Record 21 of Set 5 | port blair
# City not found. Skipping...
# Processing Record 22 of Set 5 | mount isa
# Processing Record 23 of Set 5 | san cristobal
# City not found. Skipping...
# Processing Record 24 of Set 5 | huarmey
# Processing Record 25 of Set 5 | yeppoon
# Processing Record 26 of Set 5 | fushun
# Processing Record 27 of Set 5 | severo-kurilsk
# Processing Record 28 of Set 5 | pak phanang
# Processing Record 29 of Set 5 | rucheng
# Processing Record 30 of Set 5 | barreirinha
# Processing Record 31 of Set 5 | balurghat
# Processing Record 32 of Set 5 | moose factory
# Processing Record 33 of Set 5 | nha trang
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | kodiak
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | springbok
# Processing Record 38 of Set 5 | turbat
# Processing Record 39 of Set 5 | pangody
# Processing Record 40 of Set 5 | crixas
# City not found. Skipping...
# Processing Record 41 of Set 5 | richfield
# City not found. Skipping...
# Processing Record 42 of Set 5 | teahupoo
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | labuhan
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | cagsiay
# Processing Record 47 of Set 5 | mabaruma
# Processing Record 48 of Set 5 | arona
# Processing Record 49 of Set 5 | saint-michel-des-saints
# City not found. Skipping...
# Processing Record 50 of Set 5 | susanville
# City not found. Skipping...
# Processing Record 1 of Set 6 | gela
# Processing Record 2 of Set 6 | berlevag
# Processing Record 3 of Set 6 | chapais
# City not found. Skipping...
# Processing Record 4 of Set 6 | tateyama
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | asau
# Processing Record 7 of Set 6 | faya
# Processing Record 8 of Set 6 | alta floresta
# Processing Record 9 of Set 6 | okhotsk
# Processing Record 10 of Set 6 | leerdam
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | dali
# Processing Record 14 of Set 6 | pozo colorado
# Processing Record 15 of Set 6 | flinders
# Processing Record 16 of Set 6 | erenhot
# Processing Record 17 of Set 6 | puerto quijarro
# Processing Record 18 of Set 6 | cabedelo
# Processing Record 19 of Set 6 | vila velha
# Processing Record 20 of Set 6 | capaci
# Processing Record 21 of Set 6 | cap-aux-meules
# Processing Record 22 of Set 6 | at-bashi
# Processing Record 23 of Set 6 | vega de alatorre
# Processing Record 24 of Set 6 | baniyas
# Processing Record 25 of Set 6 | grafton
# Processing Record 26 of Set 6 | havre
# Processing Record 27 of Set 6 | lagos
# Processing Record 28 of Set 6 | salta
# Processing Record 29 of Set 6 | anchorage
# Processing Record 30 of Set 6 | rengo
# Processing Record 31 of Set 6 | malartic
# Processing Record 32 of Set 6 | la orilla
# Processing Record 33 of Set 6 | bengkulu
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | ludza
# Processing Record 36 of Set 6 | taltal
# Processing Record 37 of Set 6 | jumla
# Processing Record 38 of Set 6 | tingo maria
# Processing Record 39 of Set 6 | aksu
# Processing Record 40 of Set 6 | batagay-alyta
# Processing Record 41 of Set 6 | mwense
# Processing Record 42 of Set 6 | kodarma
# Processing Record 43 of Set 6 | necochea
# Processing Record 44 of Set 6 | tsogni
# Processing Record 45 of Set 6 | bethel
# Processing Record 46 of Set 6 | qingyuan
# Processing Record 47 of Set 6 | lasa
# Processing Record 48 of Set 6 | kushmurun
# Processing Record 49 of Set 6 | bhadrak
# Processing Record 50 of Set 6 | talnakh
# Processing Record 1 of Set 7 | pitiquito
# Processing Record 2 of Set 7 | denpasar
# Processing Record 3 of Set 7 | bocas del toro
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | koshki
# Processing Record 6 of Set 7 | ust-tsilma
# Processing Record 7 of Set 7 | nampula
# Processing Record 8 of Set 7 | lakota
# Processing Record 9 of Set 7 | tocopilla
# Processing Record 10 of Set 7 | babol
# Processing Record 11 of Set 7 | rocafuerte
# Processing Record 12 of Set 7 | tucuman
# Processing Record 13 of Set 7 | manicore
# Processing Record 14 of Set 7 | maun
# Processing Record 15 of Set 7 | nanakuli
# Processing Record 16 of Set 7 | skjervoy
# Processing Record 17 of Set 7 | linkou
# Processing Record 18 of Set 7 | guane
# Processing Record 19 of Set 7 | los llanos de aridane
# Processing Record 20 of Set 7 | tsaritsani
# Processing Record 21 of Set 7 | thunder bay
# Processing Record 22 of Set 7 | great yarmouth
# Processing Record 23 of Set 7 | tomatlan
# Processing Record 24 of Set 7 | santa cruz
# Processing Record 25 of Set 7 | the valley
# Processing Record 26 of Set 7 | micheweni
# Processing Record 27 of Set 7 | praya
# Processing Record 28 of Set 7 | ashland
# Processing Record 29 of Set 7 | tiznit
# Processing Record 30 of Set 7 | dongsheng
# Processing Record 31 of Set 7 | north platte
# Processing Record 32 of Set 7 | nara
# Processing Record 33 of Set 7 | saint-augustin
# Processing Record 34 of Set 7 | phalaborwa
# Processing Record 35 of Set 7 | mazagao
# Processing Record 36 of Set 7 | caconda
# Processing Record 37 of Set 7 | coos bay
# Processing Record 38 of Set 7 | hailey
# Processing Record 39 of Set 7 | ribeirao branco
# Processing Record 40 of Set 7 | koshurnikovo
# Processing Record 41 of Set 7 | krasnoselkup
# Processing Record 42 of Set 7 | portland
# Processing Record 17 of Set 9 | san quintin
# City not found. Skipping...
# Processing Record 18 of Set 9 | natitingou
# Processing Record 19 of Set 9 | plettenberg bay
# Processing Record 20 of Set 9 | saint-louis
# Processing Record 21 of Set 9 | pemba
# City not found. Skipping...
# Processing Record 22 of Set 9 | lata
# Processing Record 23 of Set 9 | yepifan
# Processing Record 24 of Set 9 | novoagansk
# Processing Record 25 of Set 9 | skelleftea
# Processing Record 26 of Set 9 | taywarah
# Processing Record 27 of Set 9 | koson
# Processing Record 28 of Set 9 | big rapids
# Processing Record 29 of Set 9 | beloha
# Processing Record 30 of Set 9 | ewa beach
# Processing Record 31 of Set 9 | ponta do sol
# Processing Record 32 of Set 9 | takab
# Processing Record 33 of Set 9 | inhambane
# Processing Record 34 of Set 9 | toora-khem
# Processing Record 35 of Set 9 | wufeng
# City not found. Skipping...
# Processing Record 36 of Set 9 | kenai
# Processing Record 37 of Set 9 | kavaratti
# Processing Record 38 of Set 9 | tyulgan
# Processing Record 39 of Set 9 | svetlogorsk
# Processing Record 40 of Set 9 | deputatskiy
# Processing Record 41 of Set 9 | touros
# Processing Record 42 of Set 9 | awjilah
# Processing Record 43 of Set 9 | fort-shevchenko
# Processing Record 44 of Set 9 | filingue
# Processing Record 45 of Set 9 | laguna
# Processing Record 46 of Set 9 | ust-shonosha
# Processing Record 47 of Set 9 | padang
# Processing Record 48 of Set 9 | qaqortoq
# City not found. Skipping...
# Processing Record 49 of Set 9 | khuzdar
# Processing Record 50 of Set 9 | unguia
# Processing Record 1 of Set 10 | villarrica
# Processing Record 2 of Set 10 | mushie
# Processing Record 3 of Set 10 | manggar
# Processing Record 4 of Set 10 | bima
# Processing Record 5 of Set 10 | antalaha
# Processing Record 6 of Set 10 | kautokeino
# Processing Record 7 of Set 10 | kudahuvadhoo
# Processing Record 8 of Set 10 | sokoto
# Processing Record 9 of Set 10 | algiers
# Processing Record 10 of Set 10 | tobermory
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | gornopravdinsk
# Processing Record 13 of Set 10 | kamaishi
# Processing Record 14 of Set 10 | zalari
# Processing Record 15 of Set 10 | guaratinga
# Processing Record 16 of Set 10 | pisco
# Processing Record 17 of Set 10 | kawalu
# Processing Record 18 of Set 10 | kyaukse
# Processing Record 19 of Set 10 | tabuk
# Processing Record 20 of Set 10 | urmary
# Processing Record 21 of Set 10 | adre
# Processing Record 22 of Set 10 | tecoanapa
# Processing Record 23 of Set 10 | chapleau
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | yaan
# Processing Record 26 of Set 10 | luganville
# Processing Record 27 of Set 10 | acaponeta
# Processing Record 28 of Set 10 | joshimath
# Processing Record 29 of Set 10 | poum
# Processing Record 30 of Set 10 | te anau
# Processing Record 31 of Set 10 | vestmannaeyjar
# Processing Record 32 of Set 10 | luanda
# Processing Record 33 of Set 10 | marsa matruh
# Processing Record 34 of Set 10 | nova granada
# Processing Record 35 of Set 10 | invermere
# Processing Record 36 of Set 10 | rafsanjan
# Processing Record 37 of Set 10 | cortez
# Processing Record 38 of Set 10 | kralendijk
# Processing Record 39 of Set 10 | kasongo
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | geraldton
# Processing Record 42 of Set 10 | port hedland
# Processing Record 43 of Set 10 | zhanakorgan
# Processing Record 44 of Set 10 | aktas
# City not found. Skipping...
# Processing Record 45 of Set 10 | ust-karsk
# Processing Record 46 of Set 10 | mende
# Processing Record 47 of Set 10 | pipar
# Processing Record 48 of Set 10 | talara
# Processing Record 49 of Set 10 | gayeri
# Processing Record 50 of Set 10 | barentu
# Processing Record 1 of Set 11 | chicama
# Processing Record 2 of Set 11 | blantyre
# Processing Record 3 of Set 11 | goure
# Processing Record 4 of Set 11 | vendas novas
# Processing Record 5 of Set 11 | dudinka
# Processing Record 6 of Set 11 | altay
# Processing Record 7 of Set 11 | itarema
# Processing Record 8 of Set 11 | healesville
# Processing Record 9 of Set 11 | kalga
# Processing Record 10 of Set 11 | cattolica
# City not found. Skipping...
# Processing Record 11 of Set 11 | usinsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | andenes
# Processing Record 13 of Set 11 | kearney
# Processing Record 14 of Set 11 | baruun-urt
# Processing Record 15 of Set 11 | chipinge
# Processing Record 16 of Set 11 | kosa
# Processing Record 17 of Set 11 | okha
# Processing Record 18 of Set 11 | fethiye
# Processing Record 19 of Set 11 | malakal
# Processing Record 20 of Set 11 | clyde
# Processing Record 21 of Set 11 | puerto narino
# Processing Record 22 of Set 11 | caluquembe
# Processing Record 23 of Set 11 | umba
# Processing Record 24 of Set 11 | tonosho
# Processing Record 25 of Set 11 | karratha
# Processing Record 26 of Set 11 | acarau
# Processing Record 27 of Set 11 | mocuba
# Processing Record 28 of Set 11 | port macquarie
# Processing Record 29 of Set 11 | port hardy
# Processing Record 30 of Set 11 | pangnirtung
# Processing Record 31 of Set 11 | mount kisco
# Processing Record 32 of Set 11 | meulaboh
# Processing Record 33 of Set 11 | saint-francois
# Processing Record 34 of Set 11 | alyangula
# Processing Record 35 of Set 11 | cayenne
# Processing Record 36 of Set 11 | emerald
# Processing Record 37 of Set 11 | port moresby
# Processing Record 38 of Set 11 | vicuna
# Processing Record 39 of Set 11 | annau
# Processing Record 40 of Set 11 | kamennomostskoye
# Processing Record 41 of Set 11 | kolokani
# Processing Record 42 of Set 11 | kvarkeno
# Processing Record 43 of Set 11 | batticaloa
# Processing Record 44 of Set 11 | skotterud
# Processing Record 45 of Set 11 | okakarara
# Processing Record 46 of Set 11 | noyabrsk
# Processing Record 47 of Set 11 | gasa
# Processing Record 48 of Set 11 | sitka
# Processing Record 49 of Set 11 | kashi
# Processing Record 50 of Set 11 | umm kaddadah
# Processing Record 1 of Set 12 | zyryanka
# Processing Record 2 of Set 12 | ayan
# City not found. Skipping...
# Processing Record 3 of Set 12 | nuuk
# Processing Record 4 of Set 12 | middelburg
# City not found. Skipping...
# Processing Record 5 of Set 12 | cabadiangan
# Processing Record 6 of Set 12 | pinar del rio
# Processing Record 7 of Set 12 | cross lanes
# Processing Record 8 of Set 12 | wajir
# Processing Record 9 of Set 12 | iwaki
#
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
#create dictionary to dreate data frame
city_dict = {
    "City": city_list,
    "Lat": lat, 
    "Lng": lon, 
    "Max Temp": temp, 
    "Humidity": humidity,
    "Cloudiness": clouds, 
    "Wind Speed": wind_speed, 
    "Country": country, 
    "Date": date }
    
#create data frame
city_dict= pd.DataFrame(city_dict)

# %%
#export the city data into a .csv.
city_dict.to_csv("cities.csv", index=False)

# %%
#print dataframe
weather_df= pd.DataFrame(city_dict)
weather_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            cherskiy  68.7500  161.3000     33.91        88         100
# 1              hobart -42.8794  147.3294     57.06        49           0
# 2                kaeo -35.1000  173.7833     59.32        93          89
# 3         new norfolk -42.7826  147.0587     56.71        54          84
# 4    malinovoye ozero  51.6753   79.7825     74.41        29          21
# ..                ...      ...       ...       ...       ...         ...
# 554       cabadiangan   9.7531  122.4739     77.27        94         100
# 555     pinar del rio  22.4175  -83.6981     75.02        89         100
# 556       cross lanes  38.4204  -81.7907     63.61        97           9
# 557             wajir   1.7471   40.0573     75.49        72          55
# 558             iwaki  37.0500  140.8833     72.77        57          48
#
#      Wind Speed Country        Date
# 0         14.88      RU  1630990669
# 1          4.00      AU  1630990544
# 2          8.48      NZ  1630990670
# 3          5.01      AU  1630990670
# 4          8.34      RU  1630990671
# ..          ...     ...         ...
# 554        6.89      PH  1630990928
# 555        4.27      CU  1630990929
# 556        3.24      US  1630990877
# 557       15.97      KE  1630990929
# 558       10.69      JP  1630990930
#
# [559 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.figure(figsize=[10,5])

# Plot the lat vs the max temp
plt.scatter(x = latitude, y = temperature)

# Add labeling
# This extracts the date and returns it in the local time zone
# lat_time_plt = datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
# plt.xlim(-80,100)
# plt.ylim(min(temperature) - 10 , max(temperature) +10)
plt.savefig('Latitude vs. Temperature Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how hot the temperature gets along all latitudes of the selected cities. We can see that the hottest temperatures happen between -20 and 40 latitude which would include the contries of Africa and Europe.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs humidity
plt.scatter(x = weather_df['Lat'], y = weather_df['Humidity']);

# Add labeling
# This extracts the date and returns it in the local time zone
plt.title(f"Latitude vs. Humidity({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Humidity");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(humidity) - 10 , max(humidity) +10);
plt.savefig('Latitude vs. Humidity Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how humid gets along all latitudes of the selected cities. We do not see a real relationship represented here.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Cloudiness
plt.scatter(x = weather_df['Lat'], y = weather_df['Cloudiness']);

# Add labeling
# This extracts the date and returns it in the local time zone

plt.title(f"Latitude vs. Cloudiness({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Cloudiness");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) - 10 , max(clouds) +10);
plt.savefig('Latitude vs. Cloudiness Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how cloudy it gets along all latitudes of the selected cities. We do not see a real relationship represented here.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Wind
plt.scatter(x = weather_df['Lat'], y = weather_df['Wind Speed']);

# Add labeling
plt.title(f"Latitude vs. Wind Speed ({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Wind Speeds");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) , max(clouds) );
plt.savefig('Latitude vs. Wind Speed Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how windy it gets along all latitudes of the selected cities. We see that wind speeds tend to stay under 40mph along all latitudes.

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_df[weather_df['Lat']>=0]
southern = weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Max Temp'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('NH - Max Temp vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.637362174488262

# %% [markdown]
#  This plot is analyzing the relationship between a city's temperature and latitude where the city is within the Norther Hemisphere. Here we see temperatures are lower in cities where the latitude is higher. This information implies that the further away from the equator a city is, the colder it will be. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Max Temp'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('SH - Max Temp vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.490406122420223

# %% [markdown]
# This plot is analyzing the relationship between a city's temperature and latitude where the city is within the Southern Hemisphere. Here we see temperatures are higher in cities where the latitude is lower. This information implies that the closer from the equator a city is, the warmer it will be. Our r value confirms this.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Humidity'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('NH - Humidity vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0013598143538786091

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between humidity and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Humidity'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('SH - Humidity vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0017633180179353757

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between humidity and latitude. Our r value confirms this.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Cloudiness'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('NH - Cloudiness vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0013039830002489934

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Cloudiness'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('SH - Cloudiness vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.019344119128828576

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# We do, however, notice that the Northern Hemisphere is cloudier than the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Wind Speed'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('NH - Windspeed vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.040325962852439445

# %% [markdown]
# This plot is analyzing the relationship between a city's windspeed and latitude where the city is within the Northern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Wind Speed'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
plt.savefig('SH - Windspeed vs. Latitude Linear Regression.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.02141403943294999

# %% [markdown]
# This plot is analyzing the relationship between a city's windspeed and latitude where the city is within the Southern Hemisphere. Here, we do not see a relationtion between cloudiness and latitude. Our r value confirms this.
