# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from itertools import combinations
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lon=[]
temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
city_list = []

#count records and set numbers
record_num = 0
set_num = 1

# %%
print('''
Beginning Data Retrieval     
-----------------------------
''')   

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num ==50:
            set_num += 1
            record_num = 1 
            city_list.append(city)
        
        else:
            record_num += 1 
            city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city} ")
    
    except (KeyError,IndexError):
        print ("City not found. Skipping...")
        
print('''
Data Retrieval Complete    
-----------------------------
''')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | nyurba
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | narsaq
# City not found. Skipping...
# Processing Record 8 of Set 1 | verkhnetulomskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | mabaruma
# City not found. Skipping...
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | klaksvik
# Processing Record 15 of Set 1 | phalaborwa
# Processing Record 16 of Set 1 | kiama
# Processing Record 17 of Set 1 | sayyan
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | guru har sahai
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | srednekolymsk
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | ust-tsilma
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | dhidhdhoo
# Processing Record 33 of Set 1 | bayji
# Processing Record 34 of Set 1 | panchagarh
# Processing Record 35 of Set 1 | guasave
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | ponta do sol
# City not found. Skipping...
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | zhigansk
# Processing Record 40 of Set 1 | camacha
# Processing Record 41 of Set 1 | hami
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | san quintin
# Processing Record 44 of Set 1 | santarem
# Processing Record 45 of Set 1 | asfi
# Processing Record 46 of Set 1 | inuvik
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | vincennes
# Processing Record 49 of Set 1 | nabire
# City not found. Skipping...
# Processing Record 50 of Set 1 | anklam
# Processing Record 1 of Set 2 | karabulak
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | lasa
# Processing Record 14 of Set 2 | buraydah
# Processing Record 15 of Set 2 | ciudad bolivar
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | east london
# City not found. Skipping...
# Processing Record 18 of Set 2 | gidam
# Processing Record 19 of Set 2 | mananara
# City not found. Skipping...
# Processing Record 20 of Set 2 | reconquista
# Processing Record 21 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 22 of Set 2 | rafaela
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | namibe
# Processing Record 25 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record
# Processing Record 38 of Set 3 | colares
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | zeya
# Processing Record 41 of Set 3 | samarai
# Processing Record 42 of Set 3 | tura
# Processing Record 43 of Set 3 | jakarta
# Processing Record 44 of Set 3 | kadhan
# City not found. Skipping...
# Processing Record 45 of Set 3 | kirsanov
# City not found. Skipping...
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | dingle
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | arriana
# Processing Record 1 of Set 4 | minot
# Processing Record 2 of Set 4 | leh
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | contai
# Processing Record 5 of Set 4 | honningsvag
# Processing Record 6 of Set 4 | broken hill
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | kaeo
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | manesti
# Processing Record 16 of Set 4 | oga
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | orito
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | seymchan
# Processing Record 21 of Set 4 | hay river
# Processing Record 22 of Set 4 | udachnyy
# Processing Record 23 of Set 4 | bonfim
# Processing Record 24 of Set 4 | blackwater
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | pokhara
# Processing Record 28 of Set 4 | derzhavinsk
# Processing Record 29 of Set 4 | khanna
# Processing Record 30 of Set 4 | kahului
# Processing Record 31 of Set 4 | baena
# Processing Record 32 of Set 4 | tevaitoa
# Processing Record 33 of Set 4 | gisors
# Processing Record 34 of Set 4 | hambantota
# Processing Record 35 of Set 4 | hirara
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | morondava
# City not found. Skipping...
# Processing Record 38 of Set 4 | indiaroba
# Processing Record 39 of Set 4 | coahuayana
# Processing Record 40 of Set 4 | suntar
# Processing Record 41 of Set 4 | gbarnga
# Processing Record 42 of Set 4 | ndago
# Processing Record 43 of Set 4 | riberalta
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | fare
# Processing Record 46 of Set 4 | castro
# City not found. Skipping...
# Processing Record 47 of Set 4 | lagoa
# City not found. Skipping...
# Processing Record 48 of Set 4 | nhulunbuy
# Processing Record 49 of Set 4 | el paujil
# Processing Record 50 of Set 4 | magadan
# City not found. Skipping...
# Processing Record 1 of Set 5 | firminy
# Processing Record 2 of Set 5 | sistranda
# Processing Record 3 of Set 5 | xam nua
# Processing Record 4 of Set 5 | sisimiut
# City not found. Skipping...
# Processing Record 5 of Set 5 | richards bay
# Processing Record 6 of Set 5 | chimbote
# Processing Record 7 of Set 5 | katobu
# Processing Record 8 of Set 5 | the valley
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | veraval
# Processing Record 11 of Set 5 | wanaka
# Processing Record 12 of Set 5 | sadove
# Processing Record 13 of Set 5 | conde
# City not found. Skipping...
# Processing Record 14 of Set 5 | boueni
# Processing Record 15 of Set 5 | pisco
# City not found. Skipping...
# Processing Record 16 of Set 5 | amga
# Processing Record 17 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 18 of Set 5 | bima
# Processing Record 19 of Set 5 | ambon
# Processing Record 20 of Set 5 | pombia
# Processing Record 21 of Set 5 | rovira
# Processing Record 22 of Set 5 | ucluelet
# Processing Record 23 of Set 5 | invermere
# Processing Record 24 of Set 5 | mayo
# Processing Record 25 of Set 5 | birjand
# Processing Record 26 of Set 5 | tromso
# Processing Record 27 of Set 5 | port shepstone
# Processing Record 28 of Set 5 | port huron
# Processing Record 29 of Set 5 | vila velha
# Processing Record 30 of Set 5 | weligama
# Processing Record 31 of Set 5 | chuy
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | jamiltepec
# Processing Record 34 of Set 5 | tvedestrand
# Processing Record 35 of Set 5 | resistencia
# Processing Record 36 of Set 5 | hargeysa
# Processing Record 37 of Set 5 | nueva loja
# Processing Record 38 of Set 5 | havelock
# Processing Record 39 of Set 5 | mezen
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | padra
# Processing Record 43 of Set 5 | gunnedah
# Processing Record 44 of Set 5 | nautla
# City not found. Skipping...
# Processing Record 45 of Set 5 | westport
# City not found. Skipping...
# Processing Record 46 of Set 5 | corinth
# Processing Record 47 of Set 5 | beyneu
# City not found. Skipping...
# Processing Record 48 of Set 5 | caconda
# Processing Record 49 of Set 5 | tambura
# Processing Record 50 of Set 5 | coos bay
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | yellowknife
# Processing Record 3 of Set 6 | lewiston
# Processing Record 4 of Set 6 | la ronge
# Processing Record 5 of Set 6 | pervomayskoye
# Processing Record 6 of Set 6 | timizart
# Processing Record 7 of Set 6 | jalu
# Processing Record 8 of Set 6 | menongue
# Processing Record 9 of Set 6 | galiakot
# Processing Record 10 of Set 6 | montepulciano
# Processing Record 11 of Set 6 | urengoy
# Processing Record 12 of Set 6 | fairbanks
# Processing Record 13 of Set 6 | morogoro
# Processing Record 14 of Set 6 | portovelo
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | nouakchott
# Processing Record 19 of Set 6 | mandurah
# City not found. Skipping...
# Processing Record 20 of Set 6 | bitkine
# Processing Record 21 of Set 6 | peniche
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | sigli
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | tall kayf
# Processing Record 27 of Set 6 | rochegda
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | qasigiannguit
# Processing Record 30 of Set 6 | holme
# City not found. Skipping...
# Processing Record 31 of Set 6 | kenora
# Processing Record 32 of Set 6 | ambilobe
# Processing Record 33 of Set 6 | saskylakh
# Processing Record 34 of Set 6 | tateyama
# Processing Record 35 of Set 6 | nanortalik
# City not found. Skipping...
# Processing Record 36 of Set 6 | sur
# Processing Record 37 of Set 6 | chifeng
# Processing Record 38 of Set 6 | ust-maya
# Processing Record 39 of Set 6 | kuminskiy
# Processing Record 40 of Set 6 | malanje
# Processing Record 41 of Set 6 | ekhabi
# Processing Record 42 of Set 6 | manjacaze
# Processing Record 43 of Set 6 | daru
# Processing Record 44 of Set 6 | bowen
# Processing Record 45 of Set 6 | pangnirtung
# Processing Record 46 of Set 6 | acuitzio
# Processing Record 47 of Set 6 | meiganga
# Processing Record 48 of Set 6 | maniitsoq
# Processing Record 49 of Set 6 | iqaluit
# Processing Record 50 of Set 6 | masterton
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | ketchikan
# Processing Record 3 of Set 7 | jucuaran
# City not found. Skipping...
# Processing Record 4 of Set 7 | ruteng
# Processing Record 5 of Set 7 | khandbari
# Processing Record 6 of Set 7 | qianan
# Processing Record 7 of Set 7 | swan hill
# Processing Record 8 of Set 7 | irara
# Processing Record 9 of Set 7 | lakes entrance
# Processing Record 10 of Set 7 | yankton
# Processing Record 11 of Set 7 | tabou
# Processing Record 12 of Set 7 | tezu
# Processing Record 13 of Set 7 | ust-kuyga
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | altamont
# Processing Record 16 of Set 7 | juneau
# Processing Record 17 of Set 7 | sabang
# Processing Record 18 of Set 7 | taraza
# Processing Record 19 of Set 7 | komsomolskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 7 | alibag
# Processing Record 21 of Set 7 | quzhou
# Processing Record 22 of Set 7 | marau
# Processing Record 23 of Set 7 | port lincoln
# City not found. Skipping...
# Processing Record 24 of Set 7 | bull savanna
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | alugan
# Processing Record 27 of Set 7 | ayan
# Processing Record 28 of Set 7 | santiago de cuba
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | qandala
# Processing Record 31 of Set 7 | pilar
# Processing Record 32 of Set 7 | jinxiang
# City not found. Skipping...
# Processing Record 33 of Set 7 | sorland
# Processing Record 34 of Set 7 | mongu
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | zaragoza
# Processing Record 38 of Set 7 | umba
# City not found. Skipping...
# Processing Record 39 of Set 7 | tottori
# Processing Record 40 of Set 7 | sabha
# Processing Record 41 of Set 7 | beringovskiy
# Processing Record 42 of Set 7 | erenhot
# City not found. Skipping...
# Processing Record 43 of Set 7 | clemmons
# Processing Record 44 of Set 7 | darhan
# Processing Record 45 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 16 of Set 9 | torrevieja
# Processing Record 17 of Set 9 | baykit
# Processing Record 18 of Set 9 | arlit
# Processing Record 19 of Set 9 | charagua
# Processing Record 20 of Set 9 | road town
# Processing Record 21 of Set 9 | flinders
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | champerico
# Processing Record 24 of Set 9 | alta
# Processing Record 25 of Set 9 | sterling
# Processing Record 26 of Set 9 | kawalu
# Processing Record 27 of Set 9 | sept-iles
# Processing Record 28 of Set 9 | yeppoon
# Processing Record 29 of Set 9 | irbeyskoye
# Processing Record 30 of Set 9 | necochea
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | tahoua
# Processing Record 33 of Set 9 | bayir
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | naze
# Processing Record 36 of Set 9 | synya
# Processing Record 37 of Set 9 | meadow lake
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | hualmay
# Processing Record 40 of Set 9 | san angelo
# Processing Record 41 of Set 9 | opuwo
# Processing Record 42 of Set 9 | nordenham
# Processing Record 43 of Set 9 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | xining
# Processing Record 46 of Set 9 | marawi
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | dengzhou
# Processing Record 49 of Set 9 | berestechko
# Processing Record 50 of Set 9 | brazzaville
# Processing Record 1 of Set 10 | xuddur
# Processing Record 2 of Set 10 | ekangala
# Processing Record 3 of Set 10 | elmira
# Processing Record 4 of Set 10 | ixtapa
# Processing Record 5 of Set 10 | berlevag
# Processing Record 6 of Set 10 | saint-leu
# Processing Record 7 of Set 10 | tarbagatay
# Processing Record 8 of Set 10 | novorzhev
# Processing Record 9 of Set 10 | tagusao
# Processing Record 10 of Set 10 | palmer
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | lisakovsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | san giovanni in fiore
# Processing Record 14 of Set 10 | olavarria
# Processing Record 15 of Set 10 | san vicente
# Processing Record 16 of Set 10 | carbonear
# Processing Record 17 of Set 10 | juruti
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | mecca
# Processing Record 20 of Set 10 | voh
# Processing Record 21 of Set 10 | voznesenskaya
# Processing Record 22 of Set 10 | williamsburg
# Processing Record 23 of Set 10 | turukhansk
# Processing Record 24 of Set 10 | paducah
# Processing Record 25 of Set 10 | tunceli
# Processing Record 26 of Set 10 | kruisfontein
# Processing Record 27 of Set 10 | binga
# Processing Record 28 of Set 10 | maloy
# Processing Record 29 of Set 10 | tilichiki
# Processing Record 30 of Set 10 | manta
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | bria
# Processing Record 33 of Set 10 | troitskoye
# Processing Record 34 of Set 10 | banda aceh
# Processing Record 35 of Set 10 | morant bay
# Processing Record 36 of Set 10 | narasannapeta
# Processing Record 37 of Set 10 | ust-ishim
# Processing Record 38 of Set 10 | yumen
# Processing Record 39 of Set 10 | santiago del estero
# City not found. Skipping...
# Processing Record 40 of Set 10 | biak
# Processing Record 41 of Set 10 | saint-augustin
# Processing Record 42 of Set 10 | puerto madero
# Processing Record 43 of Set 10 | burns lake
# Processing Record 44 of Set 10 | marzuq
# Processing Record 45 of Set 10 | black river
# Processing Record 46 of Set 10 | vao
# Processing Record 47 of Set 10 | vila do maio
# Processing Record 48 of Set 10 | del rio
# Processing Record 49 of Set 10 | torata
# Processing Record 50 of Set 10 | san ramon
# Processing Record 1 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 11 | port blair
# Processing Record 3 of Set 11 | sorong
# Processing Record 4 of Set 11 | liku
# Processing Record 5 of Set 11 | harer
# Processing Record 6 of Set 11 | matinha
# Processing Record 7 of Set 11 | saravan
# Processing Record 8 of Set 11 | solnechnyy
# Processing Record 9 of Set 11 | vrangel
# Processing Record 10 of Set 11 | banyo
# Processing Record 11 of Set 11 | garhi khairo
# Processing Record 12 of Set 11 | raudeberg
# Processing Record 13 of Set 11 | krasnoselkup
# Processing Record 14 of Set 11 | asnaes
# Processing Record 15 of Set 11 | oconomowoc
# Processing Record 16 of Set 11 | zhangye
# Processing Record 17 of Set 11 | yokadouma
# City not found. Skipping...
# Processing Record 18 of Set 11 | salym
# Processing Record 19 of Set 11 | flin flon
# Processing Record 20 of Set 11 | itaguai
# Processing Record 21 of Set 11 | rock sound
# Processing Record 22 of Set 11 | rio grande
# Processing Record 23 of Set 11 | deming
# Processing Record 24 of Set 11 | eureka
# Processing Record 25 of Set 11 | ornes
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | acarau
# Processing Record 28 of Set 11 | pringsewu
# Processing Record 29 of Set 11 | mpika
# Processing Record 30 of Set 11 | waingapu
# Processing Record 31 of Set 11 | baruun-urt
# Processing Record 32 of Set 11 | zyryanka
# Processing Record 33 of Set 11 | tiarei
# Processing Record 34 of Set 11 | holland
# Processing Record 35 of Set 11 | olafsvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | miajadas
# Processing Record 37 of Set 11 | waipawa
# Processing Record 38 of Set 11 | churapcha
# Processing Record 39 of Set 11 | ndjole
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | quatre cocos
# Processing Record 42 of Set 11 | arman
# Processing Record 43 of Set 11 | bonavista
# City not found. Skipping...
# Processing Record 44 of Set 11 | kilindoni
# Processing Record 45 of Set 11 | burlington
# Processing Record 46 of Set 11 | asosa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 11 | tra vinh
# Processing Record 48 of Set 11 | sangar
# Processing Record 49 of Set 11 | carmen
# Processing Record 50 of Set 11 | kalmunai
# Processing Record 1 of Set 12 | makakilo city
#
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dictionary to dreate data frame
city_dict = {
    "City": city_list,
    "Lat": lat, 
    "Lng": lon, 
    "Max Temp": temp, 
    "Humidity": humidity,
    "Cloudiness": clouds, 
    "Wind Speed": wind_speed, 
    "Country": country, 
    "Date": date }
    
#create data frame
city_dict= pd.DataFrame(city_dict)

# %%
#export the city data into a .csv.
city_dict.to_csv("cities.csv", index=False)

# %%
#print dataframe
city_df= pd.DataFrame(city_dict)
city_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        upernavik  72.7868  -56.1549      4.50        83          94
# 1     san patricio  28.0170  -97.5169     36.12        38           0
# 2          rikitea -23.1203 -134.9692     20.70        54           0
# 3           nyurba  63.2842  118.3319     16.03        69          51
# 4         cidreira -30.1811  -50.2056     16.11        73           1
# ..             ...      ...       ...       ...       ...         ...
# 546       tra vinh   9.9347  106.3453     24.32        91          70
# 547         sangar  63.9242  127.4739     17.87        62           1
# 548         carmen  18.6333  -91.8333     29.98        66         100
# 549       kalmunai   7.4167   81.8167     27.31        70         100
# 550  makakilo city  21.3469 -158.0858     29.20        63           7
#
#      Wind Speed Country        Date
# 0          2.42      GL  1627163455
# 1          7.00      US  1627163484
# 2          0.64      PF  1627163613
# 3          2.36      RU  1627163614
# 4          3.11      BR  1627163461
# ..          ...     ...         ...
# 546        3.35      VN  1627163557
# 547        4.25      RU  1627163811
# 548        4.99      MX  1627163789
# 549        2.97      LK  1627163812
# 550        8.28      US  1627163812
#
# [551 rows x 9 columns]

# %%
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = city_dict['Lat']
temperature = city_dict['Max Temp']

plt.figure(figsize=(10,5))

# Plot the lat vs the max temp
plt.scatter(x = latitude, y = temperature)

# Add labeling
# This extracts the date and returns it in the local time zone
lat_time_plt = datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({city_df})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(min(temperature) - 10 , max(temperature) +10)


plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\coron\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs humidity
plt.scatter(x = city_dict['Lat'], y = city_dict['Humidity']);

# Add labeling
# This extracts the date and returns it in the local time zone
lat_hum_plt= datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d');
plt.title(f"Latitude vs. Humidity({city_df})");
plt.xlabel("Latitude");
plt.ylabel("Humidity");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(humidity) - 10 , max(humidity) +10);


plt;

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Cloudiness
plt.scatter(x = city_dict['Lat'], y = city_dict['Cloudiness']);

# Add labeling
# This extracts the date and returns it in the local time zone
lat_hum_plt= datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d');
plt.title(f"Latitude vs. Cloudiness({city_df})");
plt.xlabel("Latitude");
plt.ylabel("Cloudiness");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) - 10 , max(clouds) +10);


plt;

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Wind
plt.scatter(x = city_dict['Lat'], y = city_dict['Wind Speed']);

# Add labeling
plt.title(f"Latitude vs. Wind Speed");
plt.xlabel("Latitude");
plt.ylabel("Wind Speeds");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) - 10 , max(clouds) +10);


plt;

# %%
# Out:
# list

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
