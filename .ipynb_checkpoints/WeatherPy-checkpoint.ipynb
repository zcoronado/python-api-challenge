# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from itertools import combinations
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lon=[]
temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
city_list = []

#count records and set numbers
record_num = 0
set_num = 1

# %%
print('''
Beginning Data Retrieval     
-----------------------------
''')   

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num ==50:
            set_num += 1
            record_num = 1 
            city_list.append(city)
        
        else:
            record_num += 1 
            city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city} ")
    
    except (KeyError,IndexError):
        print ("City not found. Skipping...")
        
print('''
Data Retrieval Complete    
-----------------------------
''')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | shankargarh
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | baoro
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | lincoln
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | kahului
# Processing Record 13 of Set 1 | carauari
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | palauig
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | karpinsk
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | camocim
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | ishigaki
# Processing Record 28 of Set 1 | shishou
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | maarianhamina
# Processing Record 32 of Set 1 | ambilobe
# Processing Record 33 of Set 1 | marsa matruh
# Processing Record 34 of Set 1 | inhambane
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | baisha
# Processing Record 37 of Set 1 | khani
# City not found. Skipping...
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | christchurch
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | springbok
# Processing Record 45 of Set 1 | comodoro rivadavia
# Processing Record 46 of Set 1 | lahad datu
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | keskin
# City not found. Skipping...
# Processing Record 49 of Set 1 | fairbanks
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | nsoko
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | itarema
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | san vicente
# Processing Record 6 of Set 2 | udachnyy
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | acari
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | natal
# Processing Record 38 of Set 3 | jiuquan
# Processing Record 39 of Set 3 | jamestown
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | tual
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | rocha
# City not found. Skipping...
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | sobolevo
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | labuan
# Processing Record 2 of Set 4 | te anau
# Processing Record 3 of Set 4 | mana
# Processing Record 4 of Set 4 | najran
# Processing Record 5 of Set 4 | tautira
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | marti
# Processing Record 12 of Set 4 | san andres del rabanedo
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | kamarion
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | anloga
# Processing Record 20 of Set 4 | glamoc
# Processing Record 21 of Set 4 | dakar
# Processing Record 22 of Set 4 | pavlovskiy
# Processing Record 23 of Set 4 | saurimo
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | orange walk
# Processing Record 26 of Set 4 | svetlyy
# Processing Record 27 of Set 4 | hervey bay
# Processing Record 28 of Set 4 | uyuni
# Processing Record 29 of Set 4 | dwarka
# Processing Record 30 of Set 4 | ossora
# Processing Record 31 of Set 4 | halifax
# Processing Record 32 of Set 4 | manokwari
# Processing Record 33 of Set 4 | kampot
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | sonamura
# Processing Record 37 of Set 4 | komsomolskiy
# Processing Record 38 of Set 4 | beloha
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | erzin
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | sheridan
# Processing Record 44 of Set 4 | viedma
# Processing Record 45 of Set 4 | cam ranh
# Processing Record 46 of Set 4 | havoysund
# Processing Record 47 of Set 4 | mareeba
# Processing Record 48 of Set 4 | saint-joseph
# Processing Record 49 of Set 4 | adrar
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | provost
# Processing Record 2 of Set 5 | byron bay
# Processing Record 3 of Set 5 | rock springs
# City not found. Skipping...
# Processing Record 4 of Set 5 | namuac
# Processing Record 5 of Set 5 | bolobo
# Processing Record 6 of Set 5 | saint albans
# Processing Record 7 of Set 5 | yar-sale
# Processing Record 8 of Set 5 | eagle pass
# Processing Record 9 of Set 5 | urusha
# Processing Record 10 of Set 5 | conde
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | dharchula
# Processing Record 13 of Set 5 | venado tuerto
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | lagoa
# Processing Record 16 of Set 5 | port-cartier
# Processing Record 17 of Set 5 | guabito
# Processing Record 18 of Set 5 | sisimiut
# Processing Record 19 of Set 5 | kainantu
# Processing Record 20 of Set 5 | puquio
# Processing Record 21 of Set 5 | lorengau
# Processing Record 22 of Set 5 | ust-ilimsk
# Processing Record 23 of Set 5 | colac
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | bulgan
# Processing Record 26 of Set 5 | sorong
# City not found. Skipping...
# Processing Record 27 of Set 5 | fukue
# City not found. Skipping...
# Processing Record 28 of Set 5 | los llanos de aridane
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | kodiak
# Processing Record 31 of Set 5 | matay
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | emerald
# Processing Record 34 of Set 5 | boke
# Processing Record 35 of Set 5 | rylsk
# Processing Record 36 of Set 5 | clyde river
# City not found. Skipping...
# Processing Record 37 of Set 5 | solnechnyy
# Processing Record 38 of Set 5 | hauge
# Processing Record 39 of Set 5 | norman wells
# Processing Record 40 of Set 5 | zhanaozen
# Processing Record 41 of Set 5 | geraldton
# Processing Record 42 of Set 5 | pindwara
# Processing Record 43 of Set 5 | sarrebourg
# Processing Record 44 of Set 5 | san juan
# Processing Record 45 of Set 5 | umm kaddadah
# Processing Record 46 of Set 5 | yeppoon
# Processing Record 47 of Set 5 | naliya
# Processing Record 48 of Set 5 | mogadishu
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 50 of Set 5 | yabrud
# Processing Record 1 of Set 6 | vila franca do campo
# Processing Record 2 of Set 6 | payo
# Processing Record 3 of Set 6 | thompson
# Processing Record 4 of Set 6 | puerto carreno
# City not found. Skipping...
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | valley
# Processing Record 7 of Set 6 | nizhniy tsasuchey
# Processing Record 8 of Set 6 | ilesha
# Processing Record 9 of Set 6 | yurginskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | auki
# Processing Record 11 of Set 6 | half moon bay
# Processing Record 12 of Set 6 | labuhan
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | hue
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | malatya
# City not found. Skipping...
# Processing Record 18 of Set 6 | semnan
# City not found. Skipping...
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | andenes
# City not found. Skipping...
# Processing Record 21 of Set 6 | excelsior springs
# Processing Record 22 of Set 6 | kurchum
# Processing Record 23 of Set 6 | taketa
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | port hawkesbury
# Processing Record 26 of Set 6 | isangel
# Processing Record 27 of Set 6 | melo
# Processing Record 28 of Set 6 | tabas
# Processing Record 29 of Set 6 | bonthe
# Processing Record 30 of Set 6 | kaeo
# Processing Record 31 of Set 6 | poya
# Processing Record 32 of Set 6 | bagdarin
# Processing Record 33 of Set 6 | port keats
# Processing Record 34 of Set 6 | funadhoo
# Processing Record 35 of Set 6 | werda
# Processing Record 36 of Set 6 | santiago del estero
# Processing Record 37 of Set 6 | rovnoye
# Processing Record 38 of Set 6 | evensk
# City not found. Skipping...
# Processing Record 39 of Set 6 | winnemucca
# Processing Record 40 of Set 6 | griffith
# Processing Record 41 of Set 6 | ipixuna
# Processing Record 42 of Set 6 | cap malheureux
# Processing Record 43 of Set 6 | huarmey
# Processing Record 44 of Set 6 | telhara
# Processing Record 45 of Set 6 | askarovo
# Processing Record 46 of Set 6 | rio gallegos
# Processing Record 47 of Set 6 | pinawa
# Processing Record 48 of Set 6 | namatanai
# Processing Record 49 of Set 6 | guasdualito
# Processing Record 50 of Set 6 | mangit
# Processing Record 1 of Set 7 | krasnoselkup
# Processing Record 2 of Set 7 | sao gabriel da cachoeira
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | tolaga bay
# Processing Record 6 of Set 7 | chuy
# Processing Record 7 of Set 7 | farafangana
# Processing Record 8 of Set 7 | bethanien
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | bereda
# Processing Record 11 of Set 7 | surt
# Processing Record 12 of Set 7 | brae
# Processing Record 13 of Set 7 | san carlos de bariloche
# Processing Record 14 of Set 7 | dicabisagan
# Processing Record 15 of Set 7 | grants
# Processing Record 16 of Set 7 | huangchuan
# Processing Record 17 of Set 7 | muhos
# Processing Record 18 of Set 7 | nador
# City not found. Skipping...
# Processing Record 19 of Set 7 | san fernando
# Processing Record 20 of Set 7 | kushiro
# Processing Record 21 of Set 7 | cidreira
# Processing Record 22 of Set 7 | khasan
# Processing Record 23 of Set 7 | pitimbu
# Processing Record 24 of Set 7 | sungaipenuh
# Processing Record 25 of Set 7 | ust-tsilma
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | kavaratti
# Processing Record 28 of Set 7 | la ronge
# City not found. Skipping...
# Processing Record 29 of Set 7 | taoudenni
# City not found. Skipping...
# Processing Record 30 of Set 7 | nisia floresta
# Processing Record 31 of Set 7 | hirara
# Processing Record 32 of Set 7 | seymchan
# Processing Record 33 of Set 7 | grande prairie
# Processing Record 34 of Set 7 | macusani
# City not found. Skipping...
# Processing Record 35 of Set 7 | qianan
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | port elizabeth
# Processing Record 38 of Set 7 | vila velha
# Processing Record 39 of Set 7 | malindi
# Processing Record 40 of Set 7 | miri
# Processing Record 41 of Set 7 | chokurdakh
# Processing Record 42 of Set 7 | henties bay
# Processing Record 12 of Set 9 | lindi
# Processing Record 13 of Set 9 | dubbo
# Processing Record 14 of Set 9 | victoria
# Processing Record 15 of Set 9 | westport
# Processing Record 16 of Set 9 | mandalgovi
# Processing Record 17 of Set 9 | dubrovka
# Processing Record 18 of Set 9 | baoding
# Processing Record 19 of Set 9 | raudeberg
# Processing Record 20 of Set 9 | tainan
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | glencoe
# Processing Record 23 of Set 9 | tocopilla
# Processing Record 24 of Set 9 | mehamn
# Processing Record 25 of Set 9 | vao
# Processing Record 26 of Set 9 | ilulissat
# Processing Record 27 of Set 9 | archidona
# Processing Record 28 of Set 9 | port hueneme
# Processing Record 29 of Set 9 | faya
# Processing Record 30 of Set 9 | vangaindrano
# Processing Record 31 of Set 9 | vila
# Processing Record 32 of Set 9 | merida
# Processing Record 33 of Set 9 | mahajanga
# Processing Record 34 of Set 9 | kismayo
# Processing Record 35 of Set 9 | rafraf
# Processing Record 36 of Set 9 | basco
# Processing Record 37 of Set 9 | sokolovskoye
# Processing Record 38 of Set 9 | kindu
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | borgarnes
# Processing Record 41 of Set 9 | kisii
# Processing Record 42 of Set 9 | northam
# Processing Record 43 of Set 9 | ixtapa
# Processing Record 44 of Set 9 | naryan-mar
# Processing Record 45 of Set 9 | yenagoa
# Processing Record 46 of Set 9 | dunedin
# Processing Record 47 of Set 9 | ca mau
# Processing Record 48 of Set 9 | maragogi
# Processing Record 49 of Set 9 | marihatag
# Processing Record 50 of Set 9 | boende
# Processing Record 1 of Set 10 | doha
# Processing Record 2 of Set 10 | constitucion
# Processing Record 3 of Set 10 | kandrian
# Processing Record 4 of Set 10 | mayor pablo lagerenza
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | kentau
# Processing Record 7 of Set 10 | nelson bay
# Processing Record 8 of Set 10 | san roque
# Processing Record 9 of Set 10 | sembe
# City not found. Skipping...
# Processing Record 10 of Set 10 | isabela
# Processing Record 11 of Set 10 | placerville
# Processing Record 12 of Set 10 | marsh harbour
# Processing Record 13 of Set 10 | kalmunai
# Processing Record 14 of Set 10 | qeshm
# Processing Record 15 of Set 10 | vereeniging
# Processing Record 16 of Set 10 | kyren
# Processing Record 17 of Set 10 | anadyr
# Processing Record 18 of Set 10 | gondanglegi
# Processing Record 19 of Set 10 | aswan
# Processing Record 20 of Set 10 | mirante do paranapanema
# Processing Record 21 of Set 10 | sri aman
# Processing Record 22 of Set 10 | taybad
# Processing Record 23 of Set 10 | bandarbeyla
# Processing Record 24 of Set 10 | barra dos coqueiros
# Processing Record 25 of Set 10 | belaya gora
# Processing Record 26 of Set 10 | luderitz
# City not found. Skipping...
# Processing Record 27 of Set 10 | nouadhibou
# Processing Record 28 of Set 10 | alekseyevsk
# Processing Record 29 of Set 10 | lerwick
# Processing Record 30 of Set 10 | san quintin
# Processing Record 31 of Set 10 | shimanovsk
# Processing Record 32 of Set 10 | superior
# Processing Record 33 of Set 10 | pietarsaari
# Processing Record 34 of Set 10 | santa maria da vitoria
# Processing Record 35 of Set 10 | roald
# Processing Record 36 of Set 10 | jacqueville
# Processing Record 37 of Set 10 | maningrida
# Processing Record 38 of Set 10 | waspan
# Processing Record 39 of Set 10 | anchorage
# Processing Record 40 of Set 10 | santa marta
# Processing Record 41 of Set 10 | ostrovnoy
# Processing Record 42 of Set 10 | kudahuvadhoo
# Processing Record 43 of Set 10 | haukipudas
# Processing Record 44 of Set 10 | staryy nadym
# Processing Record 45 of Set 10 | caravelas
# Processing Record 46 of Set 10 | mmabatho
# Processing Record 47 of Set 10 | pangkalanbuun
# Processing Record 48 of Set 10 | port lincoln
# Processing Record 49 of Set 10 | cururupu
# Processing Record 50 of Set 10 | pasighat
# Processing Record 1 of Set 11 | winfield
# City not found. Skipping...
# Processing Record 2 of Set 11 | saint-francois
# Processing Record 3 of Set 11 | cayenne
# Processing Record 4 of Set 11 | bratsk
# Processing Record 5 of Set 11 | paka
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | cortez
# Processing Record 8 of Set 11 | aranos
# Processing Record 9 of Set 11 | alanib
# City not found. Skipping...
# Processing Record 10 of Set 11 | pokhara
# City not found. Skipping...
# Processing Record 11 of Set 11 | pangody
# Processing Record 12 of Set 11 | sao jose da coroa grande
# Processing Record 13 of Set 11 | urk
# Processing Record 14 of Set 11 | amuntai
# Processing Record 15 of Set 11 | kieta
# Processing Record 16 of Set 11 | grottammare
# Processing Record 17 of Set 11 | port hedland
# Processing Record 18 of Set 11 | tadine
# Processing Record 19 of Set 11 | yulara
# Processing Record 20 of Set 11 | yarmouth
# Processing Record 21 of Set 11 | kemijarvi
# Processing Record 22 of Set 11 | buin
# Processing Record 23 of Set 11 | tosno
# Processing Record 24 of Set 11 | juneau
# Processing Record 25 of Set 11 | bantogon
# Processing Record 26 of Set 11 | eldorado
# Processing Record 27 of Set 11 | port hardy
# Processing Record 28 of Set 11 | itaituba
# Processing Record 29 of Set 11 | jumla
# Processing Record 30 of Set 11 | salavat
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | ewa beach
# Processing Record 33 of Set 11 | ugoofaaru
# Processing Record 34 of Set 11 | karatuzskoye
# Processing Record 35 of Set 11 | canutama
# Processing Record 36 of Set 11 | jiaojiang
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | margate
# Processing Record 39 of Set 11 | rohnert park
# City not found. Skipping...
# Processing Record 40 of Set 11 | beringovskiy
# Processing Record 41 of Set 11 | alta floresta
# Processing Record 42 of Set 11 | koshki
# Processing Record 43 of Set 11 | cassia
# Processing Record 44 of Set 11 | volnovakha
# Processing Record 45 of Set 11 | adre
# Processing Record 46 of Set 11 | gashua
# City not found. Skipping...
# Processing Record 47 of Set 11 | gamovo
# City not found. Skipping...
# Processing Record 48 of Set 11 | jimma
# City not found. Skipping...
# Processing Record 49 of Set 11 | noumea
# City not found. Skipping...
# Processing Record 50 of Set 11 | serowe
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | kameno
# City not found. Skipping...
# Processing Record 3 of Set 12 | pontes e lacerda
# Processing Record 4 of Set 12 | san miguel
# Processing Record 5 of Set 12 | omboue
# Processing Record 6 of Set 12 | manzil salim
# Processing Record 7 of Set 12 | hasaki
# Processing Record 8 of Set 12 | vetluzhskiy
# Processing Record 9 of Set 12 | quthing
# Processing Record 10 of Set 12 | san policarpo
# Processing Record 11 of Set 12 | chilca
# Processing Record 12 of Set 12 | mumford
#
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dictionary to dreate data frame
city_dict = {
    "City": city_list,
    "Lat": lat, 
    "Lng": lon, 
    "Max Temp": temp, 
    "Humidity": humidity,
    "Cloudiness": clouds, 
    "Wind Speed": wind_speed, 
    "Country": country, 
    "Date": date }
    
#create data frame
city_dict= pd.DataFrame(city_dict)

# %%
#export the city data into a .csv.
city_dict.to_csv("cities.csv", index=False)

# %%
#print dataframe
city_df= pd.DataFrame(city_dict)
city_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      shankargarh  25.1833   81.6167     41.90        17          24
# 1          rikitea -23.1203 -134.9692     23.73        66          90
# 2           albany  42.6001  -73.9662     12.22        68         100
# 3            baoro   5.6667   15.9667     21.41        92          76
# 4        bathsheba  13.2167  -59.5167     26.00        65          20
# ..             ...      ...       ...       ...       ...         ...
# 557    vetluzhskiy  58.3902   45.4654     20.38        63           6
# 558        quthing -30.4000   27.7003     10.38        49           2
# 559  san policarpo  12.1791  125.5072     29.09        77          73
# 560         chilca -12.5211  -76.7372     16.67        94          90
# 561        mumford   5.2618   -0.7590     25.71        89          96
#
#      Wind Speed Country        Date
# 0          3.55      IN  1621143669
# 1          7.94      PF  1621143670
# 2          1.22      US  1621143563
# 3          0.77      CF  1621143670
# 4          8.23      BB  1621143671
# ..          ...     ...         ...
# 557        4.58      RU  1621143872
# 558        1.55      LS  1621143845
# 559        3.68      PH  1621143872
# 560        2.06      PE  1621143873
# 561        3.22      GH  1621143873
#
# [562 rows x 9 columns]

# %%
type(city_dict)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = city_dict['Lat']
temperature = city_dict['Max Temp']

plt.figure(figsize=(10,5))

# Plot the lat vs the max temp
plt.scatter(x = latitude, y = temperature)

# Add labeling
# This extracts the date and returns it in the local time zone
lat_time_plt = datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({city_df})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(min(temperature) - 10 , max(temperature) +10)


plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs humidity
plt.scatter(x = city_dict['Lat'], y = city_dict['Humidity']);

# Add labeling
# This extracts the date and returns it in the local time zone
lat_hum_plt= datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d');
plt.title(f"Latitude vs. Humidity({city_df})");
plt.xlabel("Latitude");
plt.ylabel("Humidity");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(humidity) - 10 , max(humidity) +10);


plt.show();

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
