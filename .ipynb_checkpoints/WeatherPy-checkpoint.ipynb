# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from itertools import combinations
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lon=[]
temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
city_list = []

#count records and set numbers
record_num = 0
set_num = 1

# %%
print('''
Beginning Data Retrieval     
-----------------------------
''')   

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num ==50:
            set_num += 1
            record_num = 1 
            city_list.append(city)
        
        else:
            record_num += 1 
            city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city} ")
    
    except (KeyError,IndexError):
        print ("City not found. Skipping...")
        
print('''
Data Retrieval Complete    
-----------------------------
''')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | fort nelson
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | taiyuan
# City not found. Skipping...
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | kozhva
# Processing Record 6 of Set 1 | tamala
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | kaseda
# Processing Record 11 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 12 of Set 1 | talara
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | fuerte olimpo
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | rawson
# City not found. Skipping...
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | margate
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | isangel
# Processing Record 26 of Set 1 | otacilio costa
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | padang
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | bambous virieux
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | da nang
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | birao
# Processing Record 36 of Set 1 | kommunisticheskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | nisia floresta
# Processing Record 41 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | fenoarivo
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | pirgos
# Processing Record 48 of Set 1 | vila velha
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | sinnar
# City not found. Skipping...
# Processing Record 3 of Set 2 | ola
# Processing Record 4 of Set 2 | la ciotat
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | ngama
# Processing Record 7 of Set 2 | hami
# Processing Record 8 of Set 2 | atuona
# City not found. Skipping...
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | santa lucia
# City not found. Skipping...
# Processing Record 11 of Set 2 | hervey bay
# Processing Record 12 of Set 2 | khuzhir
# Processing Record 13 of Set 2 | veraval
# Processing Record 14 of Set 2 | tengzhou
# Processing Record 15 of Set 2 | ribeira grande
# City not found. Skipping...
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | waddan
# Processing Record 18 of Set 2 | constitucion
# Processing Record 19 of Set 2 | codrington
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | sigli
# Processing Record 24 of Set 2 | kenai
# City not found. Skipping...
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | ixtapa
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | ust-nera
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | talas
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | pochutla
# City not found. Skipping...
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | falam
# Processing Record 37 of Set 2 | port-gentil
# Processing Record 38 of Set 2 | arkhangelsk
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | brawley
# Processing Record 41 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 42 of Set 2 | nelson bay
# Processing Record 43 of Set 2 | bellevue
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | merauke
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | skjervoy
# Processing Record 49 of Set 2 | amiens
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | bilibino
# Processing Record 2 of Set 3 | bereda
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | belmonte
# City not found. Skipping...
# Processing Record 5 of Set 3 | natal
# Processing Record 6 of Set 3 | diplo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | parambu
# Processing Record 10 of Set 3 | cap malheureux
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | kashan
# Processing Record 14 of Set 3 | chuy
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | dori
# City not found. Skipping...
# Processing Record 19 of Set 3 | florianopolis
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | betare oya
# Processing Record 22 of Set 3 | chifeng
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | lixourion
# Processing Record 25 of Set 3 | biskupiec
# Processing Record 26 of Set 3 | flin flon
# Processing Record 27 of Set 3 | korla
# Processing Record 28 of Set 3 | saquena
# Processing Record 29 of Set 3 | kloulklubed
# Processing Record 30 of Set 3 | mahendranagar
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | dareda
# Processing Record 33 of Set 3 | cimarron hills
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | mantua
# Processing Record 36 of Set 3 | kraliky
# Processing Record 37 of Set 3 | kotli loharan
# Processing Record 38 of Set 3 | burhar
# Processing Record 39 of Set 3 | puerto escondido
# Processing Record 40 of Set 3 | marienburg
# Processing Record 41 of Set 3 | xining
# Processing Record 42 of Set 3 | kipushi
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | zhezkazgan
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | caravelas
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | sweetwater
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | marzuq
# Processing Record 2 of Set 4 | aleksandrov gay
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | rabo de peixe
# Processing Record 7 of Set 4 | luganville
# Processing Record 8 of Set 4 | saint-joseph
# Processing Record 9 of Set 4 | naryan-mar
# Processing Record 10 of Set 4 | azare
# Processing Record 11 of Set 4 | necochea
# Processing Record 12 of Set 4 | aykhal
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | vagur
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | xiangxiang
# Processing Record 17 of Set 4 | taltal
# Processing Record 18 of Set 4 | ugoofaaru
# City not found. Skipping...
# Processing Record 19 of Set 4 | kasongo-lunda
# Processing Record 20 of Set 4 | port alfred
# Processing Record 21 of Set 4 | jiwani
# Processing Record 22 of Set 4 | high rock
# City not found. Skipping...
# Processing Record 23 of Set 4 | chumikan
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | alyangula
# Processing Record 26 of Set 4 | ayr
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | zig
# Processing Record 29 of Set 4 | alta floresta
# Processing Record 30 of Set 4 | akom
# Processing Record 31 of Set 4 | olinda
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | neiafu
# Processing Record 34 of Set 4 | chardara
# Processing Record 35 of Set 4 | avarua
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | san jeronimo
# City not found. Skipping...
# Processing Record 40 of Set 4 | bershet
# Processing Record 41 of Set 4 | atascocita
# Processing Record 42 of Set 4 | sobolevo
# Processing Record 43 of Set 4 | sisophon
# Processing Record 44 of Set 4 | rawlins
# Processing Record 45 of Set 4 | tihemetsa
# Processing Record 46 of Set 4 | ampanihy
# Processing Record 47 of Set 4 | torit
# Processing Record 48 of Set 4 | numan
# Processing Record 49 of Set 4 | biak
# Processing Record 50 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | dingle
# City not found. Skipping...
# Processing Record 2 of Set 5 | sri aman
# Processing Record 3 of Set 5 | cecina
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | shingu
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | portland
# City not found. Skipping...
# Processing Record 8 of Set 5 | zeya
# Processing Record 9 of Set 5 | tual
# Processing Record 10 of Set 5 | shenzhen
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | khandyga
# Processing Record 14 of Set 5 | tan an
# Processing Record 15 of Set 5 | mocuba
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | ingraj bazar
# Processing Record 18 of Set 5 | mitsamiouli
# Processing Record 19 of Set 5 | sabang
# City not found. Skipping...
# Processing Record 20 of Set 5 | zhigansk
# Processing Record 21 of Set 5 | pangnirtung
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | nyurba
# Processing Record 25 of Set 5 | meulaboh
# Processing Record 26 of Set 5 | havelock
# Processing Record 27 of Set 5 | dryden
# City not found. Skipping...
# Processing Record 28 of Set 5 | oshikango
# Processing Record 29 of Set 5 | guerrero negro
# City not found. Skipping...
# Processing Record 30 of Set 5 | davila
# Processing Record 31 of Set 5 | conde
# City not found. Skipping...
# Processing Record 32 of Set 5 | kilindoni
# Processing Record 33 of Set 5 | saint-louis
# Processing Record 34 of Set 5 | avera
# Processing Record 35 of Set 5 | honiara
# City not found. Skipping...
# Processing Record 36 of Set 5 | qaqortoq
# Processing Record 37 of Set 5 | muros
# Processing Record 38 of Set 5 | ostersund
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | alexandria
# Processing Record 42 of Set 5 | nizwa
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | callaway
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | kailua
# Processing Record 47 of Set 5 | urazovka
# Processing Record 48 of Set 5 | mopti
# Processing Record 49 of Set 5 | sao sebastiao do passe
# Processing Record 50 of Set 5 | solnechnyy
# Processing Record 1 of Set 6 | hobyo
# Processing Record 2 of Set 6 | hofn
# Processing Record 3 of Set 6 | korsakov
# Processing Record 4 of Set 6 | pathein
# Processing Record 5 of Set 6 | tokonou
# Processing Record 6 of Set 6 | meadow lake
# Processing Record 7 of Set 6 | moirang
# Processing Record 8 of Set 6 | imbituba
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | goderich
# Processing Record 11 of Set 6 | riyadh
# Processing Record 12 of Set 6 | esmeraldas
# Processing Record 13 of Set 6 | vardo
# Processing Record 14 of Set 6 | ilula
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | broome
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | te anau
# Processing Record 19 of Set 6 | hulan
# Processing Record 20 of Set 6 | le vauclin
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | mogadishu
# Processing Record 23 of Set 6 | okato
# Processing Record 24 of Set 6 | novopokrovka
# Processing Record 25 of Set 6 | bambanglipuro
# Processing Record 26 of Set 6 | the valley
# Processing Record 27 of Set 6 | torbay
# Processing Record 28 of Set 6 | kununurra
# Processing Record 29 of Set 6 | porosozero
# Processing Record 30 of Set 6 | flinders
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | sampit
# Processing Record 33 of Set 6 | tecoanapa
# Processing Record 34 of Set 6 | vao
# Processing Record 35 of Set 6 | constantine
# City not found. Skipping...
# Processing Record 36 of Set 6 | reconquista
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | sozimskiy
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | katsuura
# Processing Record 41 of Set 6 | lompoc
# Processing Record 42 of Set 6 | luang prabang
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | lake shore
# Processing Record 45 of Set 6 | kalmunai
# Processing Record 46 of Set 6 | guanica
# Processing Record 47 of Set 6 | hailar
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | rudiskes
# Processing Record 50 of Set 6 | tasiilaq
# Processing Record 1 of Set 7 | sao felix do xingu
# Processing Record 2 of Set 7 | pierre
# Processing Record 3 of Set 7 | astorga
# Processing Record 4 of Set 7 | basco
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | gasa
# Processing Record 7 of Set 7 | gorontalo
# Processing Record 8 of Set 7 | road town
# Processing Record 9 of Set 7 | arak
# Processing Record 10 of Set 7 | kindu
# Processing Record 11 of Set 7 | san luis
# Processing Record 12 of Set 7 | dalvik
# Processing Record 13 of Set 7 | tomatlan
# Processing Record 14 of Set 7 | zabid
# Processing Record 15 of Set 7 | milkovo
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | mosquera
# Processing Record 19 of Set 7 | kahului
# Processing Record 20 of Set 7 | dudinka
# Processing Record 21 of Set 7 | laurel
# Processing Record 22 of Set 7 | lagoa
# Processing Record 23 of Set 7 | greaca
# Processing Record 24 of Set 7 | augusto correa
# Processing Record 25 of Set 7 | mittagong
# Processing Record 26 of Set 7 | benemerito de las americas
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | nambour
# Processing Record 30 of Set 7 | kieta
# Processing Record 31 of Set 7 | dzhebariki-khaya
# Processing Record 32 of Set 7 | semey
# Processing Record 33 of Set 7 | abalak
# Processing Record 34 of Set 7 | sumenep
# Processing Record 35 of Set 7 | naples
# City not found. Skipping...
# Processing Record 36 of Set 7 | lac du bonnet
# Processing Record 37 of Set 7 | ovsyanka
# Processing Record 38 of Set 7 | shetpe
# Processing Record 39 of Set 7 | masvingo
# Processing Record 40 of Set 7 | grand baie
# Processing Record 41 of Set 7 | markova
# Processing Record 42 of Set 7 | bubaque
# Processing Record 43 of Set 7 | taoudenni
# Processing Record 44 of Set 7 | ozernovskiy
# City not found. Skipping...
# Processing Record 45 of Set 7 | creel
# Processing Record 46 of Set 7 | alad
# Processing Record 47 of Set 7 | bako
# Processing Record 48 of Set 7 | tokat
# Processing Record 49 of Set 7 | mazatlan
# Processing Record 50 of Set 7 | llangefni
# Processing Record 1 of Set 8 | paris
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | severo-kurilsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | iskateley
# Processing Record 5 of Set 8 | alekseyevsk
# Processing Record 6 of Set 8 | mutis
# Processing Record 7 of Set 8 | pine bluff
# Processing Record 8 of Set 8 | port hedland
# Processing Record 9 of Set 8 | ostrovnoy
# Processing Record 10 of Set 8 | mayo
# Processing Record 11 of Set 8 | deputatskiy
# Processing Record 12 of Set 8 | half moon bay
# Processing Record 13 of Set 8 | namuac
# Processing Record 14 of Set 8 | pacifica
# Processing Record 15 of Set 8 | dehloran
# Processing Record 16 of Set 8 | cham
# Processing Record 17 of Set 8 | de haan
# Processing Record 18 of Set 8 | tarasovskiy
# Processing Record 19 of Set 8 | sept-iles
# Processing Record 20 of Set 8 | madera
# Processing Record 21 of Set 8 | vengerovo
# Processing Record 22 of Set 8 | yokote
# Processing Record 23 of Set 8 | wasilla
# Processing Record 24 of Set 8 | havoysund
# Processing Record 25 of Set 8 | houma
# Processing Record 26 of Set 8 | rajpur
# Processing Record 27 of Set 8 | johi
# Processing Record 28 of Set 8 | saint-michel-des-saints
# Processing Record 29 of Set 8 | ust-kuyga
# Processing Record 30 of Set 8 | ordzhonikidze
# Processing Record 31 of Set 8 | san patricio
# Processing Record 32 of Set 8 | liverpool
# Processing Record 33 of Set 8 | cordoba
# Processing Record 34 of Set 8 | valparaiso
# City not found. Skipping...
# Processing Record 35 of Set 8 | sioux lookout
# Processing Record 36 of Set 8 | cherdakly
# Processing Record 37 of Set 8 | lazarev
# Processing Record 38 of Set 8 | richards bay
# Processing Record 39 of Set 8 | charagua
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | yenagoa
# Processing Record 42 of Set 8 | yinchuan
# Processing Record 43 of Set 8 | tazovskiy
# Processing Record 44 of Set 8 | ulladulla
# Processing Record 45 of Set 8 | witu
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | matamoros
# Processing Record 48 of Set 8 | svetlogorsk
# Processing Record 49 of Set 8 | diffa
# Processing Record 50 of Set 8 | saint-francois
# Processing Record 1 of Set 9 | ransang
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | langarud
# Processing Record 4 of Set 9 | raahe
# Processing Record 5 of Set 9 | adre
# Processing Record 6 of Set 9 | maridi
# Processing Record 7 of Set 9 | gvarv
# Processing Record 8 of Set 9 | nichinan
# Processing Record 9 of Set 9 | salalah
# Processing Record 10 of Set 9 | iralaya
# Processing Record 11 of Set 9 | aloleng
# Processing Record 12 of Set 9 | toamasina
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | stephenville
# Processing Record 15 of Set 9 | longyan
# Processing Record 16 of Set 9 | touros
# Processing Record 17 of Set 9 | nuuk
# Processing Record 18 of Set 9 | sao joao da barra
# Processing Record 19 of Set 9 | sao miguel do araguaia
# Processing Record 20 of Set 9 | ust-maya
# Processing Record 21 of Set 9 | wonthaggi
# Processing Record 22 of Set 9 | kysyl-syr
# Processing Record 23 of Set 9 | norfolk
# Processing Record 24 of Set 9 | san cristobal
# Processing Record 25 of Set 9 | igrim
# Processing Record 26 of Set 9 | skovorodino
# Processing Record 27 of Set 9 | shaunavon
# Processing Record 28 of Set 9 | trincomalee
# Processing Record 29 of Set 9 | pacific grove
# Processing Record 30 of Set 9 | riviere-au-renard
# Processing Record 31 of Set 9 | laguna
# Processing Record 32 of Set 9 | general pico
# Processing Record 33 of Set 9 | bianzhuang
# Processing Record 34 of Set 9 | siocon
# Processing Record 35 of Set 9 | manta
# Processing Record 36 of Set 9 | ivrea
# Processing Record 37 of Set 9 | urumqi
# City not found. Skipping...
# Processing Record 38 of Set 9 | saldanha
# Processing Record 39 of Set 9 | almenara
# Processing Record 40 of Set 9 | naliya
# Processing Record 41 of Set 9 | serenje
# Processing Record 42 of Set 9 | kavaratti
# City not found. Skipping...
# Processing Record 43 of Set 9 | palana
# Processing Record 44 of Set 9 | quchan
# Processing Record 45 of Set 9 | moose factory
# Processing Record 46 of Set 9 | karmala
# Processing Record 47 of Set 9 | stoughton
# Processing Record 48 of Set 9 | erdenet
# Processing Record 49 of Set 9 | ifakara
# Processing Record 50 of Set 9 | lodja
# Processing Record 1 of Set 10 | synya
# Processing Record 2 of Set 10 | deloraine
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | esperance
# Processing Record 5 of Set 10 | faya
# Processing Record 6 of Set 10 | aasiaat
# Processing Record 7 of Set 10 | solvychegodsk
# Processing Record 8 of Set 10 | imeni zhelyabova
# Processing Record 9 of Set 10 | nur
# Processing Record 10 of Set 10 | raufoss
# Processing Record 11 of Set 10 | seoul
# Processing Record 12 of Set 10 | baykit
# Processing Record 13 of Set 10 | kiama
# Processing Record 14 of Set 10 | mahibadhoo
# Processing Record 15 of Set 10 | horsham
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 10 | sokolo
# Processing Record 17 of Set 10 | diamantino
# Processing Record 18 of Set 10 | meybod
# Processing Record 19 of Set 10 | cherskiy
# Processing Record 20 of Set 10 | kigorobya
# Processing Record 21 of Set 10 | opuwo
# Processing Record 22 of Set 10 | saint george
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | mackenzie
# Processing Record 25 of Set 10 | ati
# Processing Record 26 of Set 10 | entebbe
# Processing Record 27 of Set 10 | soloneshnoye
# Processing Record 28 of Set 10 | phuntsholing
# Processing Record 29 of Set 10 | kaeo
# Processing Record 30 of Set 10 | chapais
# Processing Record 31 of Set 10 | kholodnyy
# Processing Record 32 of Set 10 | apache junction
# Processing Record 33 of Set 10 | selma
# Processing Record 34 of Set 10 | kharan
# Processing Record 35 of Set 10 | raudeberg
# Processing Record 36 of Set 10 | kuvandyk
# Processing Record 37 of Set 10 | ca mau
# Processing Record 38 of Set 10 | westport
# Processing Record 39 of Set 10 | boden
# Processing Record 40 of Set 10 | oistins
# Processing Record 41 of Set 10 | kelvington
# Processing Record 42 of Set 10 | sulangan
# Processing Record 43 of Set 10 | saint andrews
# Processing Record 44 of Set 10 | cayenne
# Processing Record 45 of Set 10 | bosaso
# Processing Record 46 of Set 10 | cap-aux-meules
# Processing Record 47 of Set 10 | ardakan
# City not found. Skipping...
# Processing Record 48 of Set 10 | camargo
# Processing Record 49 of Set 10 | polis
# Processing Record 50 of Set 10 | bentiu
# Processing Record 1 of Set 11 | razole
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | tezu
# Processing Record 4 of Set 11 | carnot
# Processing Record 5 of Set 11 | lasa
# Processing Record 6 of Set 11 | san felipe
# Processing Record 7 of Set 11 | allapalli
# Processing Record 8 of Set 11 | casambalangan
# Processing Record 9 of Set 11 | khakhea
# Processing Record 10 of Set 11 | camacha
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | louga
# Processing Record 13 of Set 11 | aksu
# Processing Record 14 of Set 11 | bay roberts
# Processing Record 15 of Set 11 | goya
# City not found. Skipping...
# Processing Record 16 of Set 11 | marsa matruh
# Processing Record 17 of Set 11 | osypenko
# Processing Record 18 of Set 11 | wattegama
# Processing Record 19 of Set 11 | norrtalje
# Processing Record 20 of Set 11 | bathsheba
# Processing Record 21 of Set 11 | esna
# Processing Record 22 of Set 11 | mao
# Processing Record 23 of Set 11 | abu kamal
# Processing Record 24 of Set 11 | mwene-ditu
# Processing Record 25 of Set 11 | snezhnogorsk
# Processing Record 26 of Set 11 | george town
# Processing Record 27 of Set 11 | banda
# Processing Record 28 of Set 11 | belgrade
# Processing Record 29 of Set 11 | mumbwa
# Processing Record 30 of Set 11 | launceston
# Processing Record 31 of Set 11 | yarim
# Processing Record 32 of Set 11 | marshfield
# Processing Record 33 of Set 11 | nauta
# Processing Record 34 of Set 11 | khorramshahr
# Processing Record 35 of Set 11 | gazli
# City not found. Skipping...
# Processing Record 36 of Set 11 | kargasok
# Processing Record 37 of Set 11 | monrovia
# Processing Record 38 of Set 11 | walvis bay
# City not found. Skipping...
# Processing Record 39 of Set 11 | kadaura
# Processing Record 40 of Set 11 | lavrentiya
# Processing Record 41 of Set 11 | olafsvik
# Processing Record 42 of Set 11 | tanta
# Processing Record 43 of Set 11 | maba
# Processing Record 44 of Set 11 | rondonopolis
# Processing Record 45 of Set 11 | tiznit
# Processing Record 46 of Set 11 | anamur
# Processing Record 47 of Set 11 | santa maria
# Processing Record 48 of Set 11 | teguldet
# Processing Record 49 of Set 11 | naze
# Processing Record 50 of Set 11 | kinsale
# Processing Record 1 of Set 12 | yacuiba
# Processing Record 2 of Set 12 | yumen
# Processing Record 3 of Set 12 | campos altos
# Processing Record 4 of Set 12 | altay
# Processing Record 5 of Set 12 | cerro azul
# Processing Record 6 of Set 12 | magan
# Processing Record 7 of Set 12 | estelle
# Processing Record 8 of Set 12 | moerai
# Processing Record 9 of Set 12 | kodinsk
# Processing Record 10 of Set 12 | bernalda
# Processing Record 11 of Set 12 | castelo do piaui
#
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
#create dictionary to dreate data frame
city_dict = {
    "City": city_list,
    "Lat": lat, 
    "Lng": lon, 
    "Max Temp": temp, 
    "Humidity": humidity,
    "Cloudiness": clouds, 
    "Wind Speed": wind_speed, 
    "Country": country, 
    "Date": date }
    
#create data frame
city_dict= pd.DataFrame(city_dict)

# %%
#export the city data into a .csv.
city_dict.to_csv("cities.csv", index=False)

# %%
#print dataframe
weather_df= pd.DataFrame(city_dict)
weather_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         fort nelson  58.8053 -122.7002     54.75        58           3
# 1        punta arenas -53.1500  -70.9167     41.99        89          36
# 2             taiyuan  37.8694  112.5603     71.46        46           0
# 3               sitka  57.0531 -135.3300     57.09        88          75
# 4              kozhva  65.1073   57.0459     39.20        86         100
# ..                ...      ...       ...       ...       ...         ...
# 556           estelle  29.8458  -90.1067     80.01        81           1
# 557            moerai -22.4333 -151.3333     71.82        76         100
# 558           kodinsk  58.6881   99.1844     45.57        81         100
# 559          bernalda  40.4128   16.6920     71.76        90          52
# 560  castelo do piaui  -5.3222  -41.5525     77.90        65          58
#
#      Wind Speed Country        Date
# 0          5.79      CA  1630987720
# 1          6.31      CL  1630987324
# 2          6.71      CN  1630987720
# 3          4.61      US  1630987503
# 4         12.28      RU  1630987721
# ..          ...     ...         ...
# 556        0.00      US  1630987908
# 557       23.15      PF  1630987909
# 558        2.37      RU  1630987909
# 559        7.65      IT  1630987909
# 560        4.07      BR  1630987910
#
# [561 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.figure(figsize=[10,5])

# Plot the lat vs the max temp
plt.scatter(x = latitude, y = temperature)

# Add labeling
# This extracts the date and returns it in the local time zone
# lat_time_plt = datetime.fromtimestamp(city_dict.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
# plt.xlim(-80,100)
# plt.ylim(min(temperature) - 10 , max(temperature) +10)
plt.savefig('Latitude vs. Temperature Plot.png', bbox_inches='tight')

# %% [markdown]
# This code is analizing how hot the temperature gets along all latitudes of the selected cities. We can that the hottest temperatures happen between -20 and 40 latitude which would include the contries of Africa and Europe.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs humidity
plt.scatter(x = weather_df['Lat'], y = weather_df['Humidity']);

# Add labeling
# This extracts the date and returns it in the local time zone
plt.title(f"Latitude vs. Humidity({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Humidity");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(humidity) - 10 , max(humidity) +10);
plt.savefig('Latitude vs. Humidity Plot.png', bbox_inches='tight')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Cloudiness
plt.scatter(x = weather_df['Lat'], y = weather_df['Cloudiness']);

# Add labeling
# This extracts the date and returns it in the local time zone

plt.title(f"Latitude vs. Cloudiness({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Cloudiness");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) - 10 , max(clouds) +10);
plt.savefig('Latitude vs. Cloudiness Plot.png', bbox_inches='tight')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5));

# Plot the lat vs Wind
plt.scatter(x = weather_df['Lat'], y = weather_df['Wind Speed']);

# Add labeling
plt.title(f"Latitude vs. Wind Speed ({time.strftime('%x')})");
plt.xlabel("Latitude");
plt.ylabel("Wind Speeds");

# Modify ticks
plt.xlim(-80,100);
plt.ylim(min(clouds) , max(clouds) );
plt.savefig('Latitude vs. Wind Speed Plot.png', bbox_inches='tight')

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_df[weather_df['Lat']>=0]
southern = weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Max Temp'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6265566504893714

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Max Temp'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Max Temp'], )
plt.title("Latitude vs Temperature Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Max Temp");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.47959159948986496

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Humidity'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Northern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0001101984316811857

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Humidity'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Humidity'], )
plt.title("Latitude vs Humidity Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Humidity");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 6.771330394600788e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Cloudiness'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.004367559519503409

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Cloudiness'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Cloudiness'], )
plt.title("Latitude vs Cloudiness Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Cloudiness");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.004909183529558131

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Wind Speed'])
regress_values = northern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(northern['Lat'], northern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(northern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.017198065926075194

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Wind Speed'])
regress_values = southern['Lat']*slope + intercept

plt.figure(figsize=(10,5));

plt.scatter(southern['Lat'], southern['Wind Speed'], )
plt.title("Latitude vs Wind Speed Plot for Southern Hemisphere"), 
plt.xlabel("Latitude"), 
plt.ylabel("Wind Speed");
plt.plot(southern['Lat'], regress_values, 'r-');
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.010358033025644708
